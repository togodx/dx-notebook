# %% [markdown]
# # Data analysis with TogoDX: Network visualization
#
# User story:
# - 研究者が何かしらの分子を定量する実験を行う。例えば遺伝子発現解析。結果として興味のある分子のIDリストを得る。
# - IDリストに掲載された分子がどのように互いに関わっているかを、統合データベースのアノテーションを用いて関係性を調べたい。
# - TogoDX を使うことで ID のフィルタ・もしくはアノテーションができる（map your IDs）。
#     - ID の数が多い場合は特定の条件で絞り込める (例: 遺伝子なら染色体、coding gene など)。
#     - ID に対して興味のある attribute を選んでアノテーションを追加できる (例: 進化的保存度やパスウェイ、関連する疾患や薬剤の情報など)。
# - TogoDX によって得られた (view result) 情報には前提条件がある
#     - 二列目以降のカラムは primary key との繋がりは保証されているが、カラム間が直接繋がっているかどうかはわからない
#     - 行と行の間の関係性はカラムのIDの一致によって繋がっていることがわかるが、テーブル形式では人間が解釈しづらい
# - TogoDX によって絞り込み and/or アノテーションが付加されたデータに対してnotebookでネットワーク可視化を実行する
#     - TogoDX のバックエンドにもなっている、IDとIDを接続する TogoID の情報を利用する
#     - 同じ行に含まれるカラム同士がどのようなパスで繋がっているかがわかる
#     - 行と行がどのようなルートで繋がっているか、あるいは独立しているかがわかる
#     - 結果として、単なる分子のリストから、より重要な分子、あるいは分子のグループを見出すことができる。
#         - ハブになっている分子、あるいは独立している分子を標的にした実験をデザインするなどのアクションを起こすことができる。
#
# Reference:
# - Enrichr-KG https://maayanlab.cloud/enrichr-kg
#     - 趣旨は似ている、用意されているデータセット・可視化に使えるデータセット数に制限がある

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
from scipy import stats

# %%
pd.set_option('display.max_rows', 100)

# %%
import sys
from urllib.request import urlopen
import json
import time

# %%
# !{sys.executable} -m pip install pyyaml --quiet
import yaml

# %%
# !{sys.executable} -m pip install pyvis --quiet
# https://pyvis.readthedocs.io/
from pyvis.network import Network

# %% [markdown]
# ## Load dataset

# %%
data_path = "../data/togodx-20230217-12655.tsv"
d = pd.read_table(data_path)
d
# Out:
#       orig_dataset       orig_entry orig_label        dest_dataset  \
# 0     ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 1     ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 2     ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 3     ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 4     ensembl_gene  ENSG00000172915       NBEA            ncbigene
# ...            ...              ...        ...                 ...
# 4529  ensembl_gene  ENSG00000157933        SKI             uniprot
# 4530  ensembl_gene  ENSG00000157933        SKI             uniprot
# 4531  ensembl_gene  ENSG00000157933        SKI             uniprot
# 4532  ensembl_gene  ENSG00000157933        SKI             uniprot
# 4533  ensembl_gene  ENSG00000157933        SKI               mondo
#
#            dest_entry                                       node  \
# 0     ENST00000379939                 transcript_biotype_ensembl
# 1     ENST00000400445                 transcript_biotype_ensembl
# 2     ENST00000537702                 transcript_biotype_ensembl
# 3     ENST00000629018                 transcript_biotype_ensembl
# 4               26960  gene_evolutionary_conservation_homologene
# ...               ...                                        ...
# 4529           P12755   protein_disease_related_proteins_uniprot
# 4530           P12755           structure_data_existence_uniprot
# 4531           P12755   interaction_proteins_in_pathway_reactome
# 4532           P12755   interaction_proteins_in_pathway_reactome
# 4533          0008426                     disease_diseases_mondo
#
#                                 value
# 0                      protein coding
# 1                      protein coding
# 2                      protein coding
# 3                      protein coding
# 4                        Insect, Worm
# ...                               ...
# 4529                  Disease variant
# 4530     Proteins with structure data
# 4531               Signaling Pathways
# 4532  Gene expression (Transcription)
# 4533        human disease or disorder
#
# [4534 rows x 7 columns]

# %%
d.describe()
# Out:
#         orig_dataset       orig_entry orig_label dest_dataset dest_entry  \
# count           4534             4534       4534         4534       4534
# unique             1              154        154            4       1894
# top     ensembl_gene  ENSG00000044115     CTNNA1      uniprot        836
# freq            4534              126        126         2528         19
#
#                                             node           value
# count                                       4534            4534
# unique                                         8              99
# top     interaction_proteins_in_pathway_reactome  protein coding
# freq                                         903             885

# %%
d['node'].unique()
# Out:
# array(['transcript_biotype_ensembl',
#        'gene_evolutionary_conservation_homologene',
#        'gene_molecular_function_ncbigene',
#        'gene_biological_process_ncbigene',
#        'protein_disease_related_proteins_uniprot',
#        'structure_data_existence_uniprot',
#        'interaction_proteins_in_pathway_reactome',
#        'disease_diseases_mondo'], dtype=object)

# %% [markdown]
# ## Extract subset

# %%
first_row_orig_id = d.head(1)['orig_entry'][0]
first_row_orig_id
# Out:
# 'ENSG00000172915'

# %%
orig_id = first_row_orig_id
subset = d[d['orig_entry'] == orig_id]
subset
# Out:
#     orig_dataset       orig_entry orig_label        dest_dataset  \
# 0   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 1   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 2   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 3   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 4   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 5   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 6   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 7   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 8   ensembl_gene  ENSG00000172915       NBEA             uniprot
# 9   ensembl_gene  ENSG00000172915       NBEA             uniprot
# 10  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 11  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 12  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 13  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 14  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 15  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 16  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 17  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 18  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 19  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 20  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 21  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 22  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 23  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 24  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 25  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 26  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 27  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 28  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 29  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 30  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 31  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 32  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 33  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 34  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 35  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 36  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 37  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 38  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 39  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 40  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 41  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 42  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 43  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 44  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 45  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 46  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 47  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 48  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 49  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 50  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 51  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 52  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 53  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 54  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 55  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 56  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 57  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 58  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 59  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 60  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 61  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 62  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 63  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 64  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 65  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 66  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 67  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 68  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 69  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 70  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 71  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 72  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 73  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 74  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 75  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 76  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 77  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 78  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 79  ensembl_gene  ENSG00000172915       NBEA               mondo
#
#          dest_entry                                       node  \
# 0   ENST00000379939                 transcript_biotype_ensembl
# 1   ENST00000400445                 transcript_biotype_ensembl
# 2   ENST00000537702                 transcript_biotype_ensembl
# 3   ENST00000629018                 transcript_biotype_ensembl
# 4             26960  gene_evolutionary_conservation_homologene
# 5             26960           gene_molecular_function_ncbigene
# 6             26960           gene_biological_process_ncbigene
# 7             26960           gene_biological_process_ncbigene
# 8        A0A0D9SF28   protein_disease_related_proteins_uniprot
# 9        A0A8I5KQL6   protein_disease_related_proteins_uniprot
# 10       A0A8I5KQP5   protein_disease_related_proteins_uniprot
# 11       A0A8I5KRX1   protein_disease_related_proteins_uniprot
# 12       A0A8I5KRZ1   protein_disease_related_proteins_uniprot
# 13       A0A8I5KS18   protein_disease_related_proteins_uniprot
# 14       A0A8I5KS58   protein_disease_related_proteins_uniprot
# 15       A0A8I5KSX3   protein_disease_related_proteins_uniprot
# 16       A0A8I5KTV6   protein_disease_related_proteins_uniprot
# 17       A0A8I5KTY1   protein_disease_related_proteins_uniprot
# 18       A0A8I5KWL1   protein_disease_related_proteins_uniprot
# 19       A0A8I5KX92   protein_disease_related_proteins_uniprot
# 20       A0A8I5KXL4   protein_disease_related_proteins_uniprot
# 21       A0A8I5KXR7   protein_disease_related_proteins_uniprot
# 22       A0A8I5KXW8   protein_disease_related_proteins_uniprot
# 23       A0A8I5KXY8   protein_disease_related_proteins_uniprot
# 24       A0A8I5KZ13   protein_disease_related_proteins_uniprot
# 25       A0A8I5QJB2   protein_disease_related_proteins_uniprot
# 26       A0A8I5QJQ0   protein_disease_related_proteins_uniprot
# 27       A0A8I5QKR1   protein_disease_related_proteins_uniprot
# 28       A0A8I5QKR6   protein_disease_related_proteins_uniprot
# 29           Q5T321   protein_disease_related_proteins_uniprot
# 30           Q8NFP9   protein_disease_related_proteins_uniprot
# 31           Q8NFP9   protein_disease_related_proteins_uniprot
# 32           Q8NFP9   protein_disease_related_proteins_uniprot
# 33       A0A0D9SF28           structure_data_existence_uniprot
# 34       A0A8I5KQL6           structure_data_existence_uniprot
# 35       A0A8I5KQP5           structure_data_existence_uniprot
# 36       A0A8I5KRX1           structure_data_existence_uniprot
# 37       A0A8I5KRZ1           structure_data_existence_uniprot
# 38       A0A8I5KS18           structure_data_existence_uniprot
# 39       A0A8I5KS58           structure_data_existence_uniprot
# 40       A0A8I5KSX3           structure_data_existence_uniprot
# 41       A0A8I5KTV6           structure_data_existence_uniprot
# 42       A0A8I5KTY1           structure_data_existence_uniprot
# 43       A0A8I5KWL1           structure_data_existence_uniprot
# 44       A0A8I5KX92           structure_data_existence_uniprot
# 45       A0A8I5KXL4           structure_data_existence_uniprot
# 46       A0A8I5KXR7           structure_data_existence_uniprot
# 47       A0A8I5KXW8           structure_data_existence_uniprot
# 48       A0A8I5KXY8           structure_data_existence_uniprot
# 49       A0A8I5KZ13           structure_data_existence_uniprot
# 50       A0A8I5QJB2           structure_data_existence_uniprot
# 51       A0A8I5QJQ0           structure_data_existence_uniprot
# 52       A0A8I5QKR1           structure_data_existence_uniprot
# 53       A0A8I5QKR6           structure_data_existence_uniprot
# 54           Q5T321           structure_data_existence_uniprot
# 55           Q8NFP9           structure_data_existence_uniprot
# 56       A0A0D9SF28   interaction_proteins_in_pathway_reactome
# 57       A0A8I5KQL6   interaction_proteins_in_pathway_reactome
# 58       A0A8I5KQP5   interaction_proteins_in_pathway_reactome
# 59       A0A8I5KRX1   interaction_proteins_in_pathway_reactome
# 60       A0A8I5KRZ1   interaction_proteins_in_pathway_reactome
# 61       A0A8I5KS18   interaction_proteins_in_pathway_reactome
# 62       A0A8I5KS58   interaction_proteins_in_pathway_reactome
# 63       A0A8I5KSX3   interaction_proteins_in_pathway_reactome
# 64       A0A8I5KTV6   interaction_proteins_in_pathway_reactome
# 65       A0A8I5KTY1   interaction_proteins_in_pathway_reactome
# 66       A0A8I5KWL1   interaction_proteins_in_pathway_reactome
# 67       A0A8I5KX92   interaction_proteins_in_pathway_reactome
# 68       A0A8I5KXL4   interaction_proteins_in_pathway_reactome
# 69       A0A8I5KXR7   interaction_proteins_in_pathway_reactome
# 70       A0A8I5KXW8   interaction_proteins_in_pathway_reactome
# 71       A0A8I5KXY8   interaction_proteins_in_pathway_reactome
# 72       A0A8I5KZ13   interaction_proteins_in_pathway_reactome
# 73       A0A8I5QJB2   interaction_proteins_in_pathway_reactome
# 74       A0A8I5QJQ0   interaction_proteins_in_pathway_reactome
# 75       A0A8I5QKR1   interaction_proteins_in_pathway_reactome
# 76       A0A8I5QKR6   interaction_proteins_in_pathway_reactome
# 77           Q5T321   interaction_proteins_in_pathway_reactome
# 78           Q8NFP9   interaction_proteins_in_pathway_reactome
# 79          0030930                     disease_diseases_mondo
#
#                               value
# 0                    protein coding
# 1                    protein coding
# 2                    protein coding
# 3                    protein coding
# 4                      Insect, Worm
# 5                           binding
# 6                  cellular process
# 7                      localization
# 8                      Unclassified
# 9                      Unclassified
# 10                     Unclassified
# 11                     Unclassified
# 12                     Unclassified
# 13                     Unclassified
# 14                     Unclassified
# 15                     Unclassified
# 16                     Unclassified
# 17                     Unclassified
# 18                     Unclassified
# 19                     Unclassified
# 20                     Unclassified
# 21                     Unclassified
# 22                     Unclassified
# 23                     Unclassified
# 24                     Unclassified
# 25                     Unclassified
# 26                     Unclassified
# 27                     Unclassified
# 28                     Unclassified
# 29                     Unclassified
# 30          Intellectual disability
# 31                  Disease variant
# 32                         Epilepsy
# 33  Proteins without structure data
# 34  Proteins without structure data
# 35  Proteins without structure data
# 36  Proteins without structure data
# 37  Proteins without structure data
# 38  Proteins without structure data
# 39  Proteins without structure data
# 40  Proteins without structure data
# 41  Proteins without structure data
# 42  Proteins without structure data
# 43  Proteins without structure data
# 44  Proteins without structure data
# 45  Proteins without structure data
# 46  Proteins without structure data
# 47  Proteins without structure data
# 48  Proteins without structure data
# 49  Proteins without structure data
# 50  Proteins without structure data
# 51  Proteins without structure data
# 52  Proteins without structure data
# 53  Proteins without structure data
# 54  Proteins without structure data
# 55     Proteins with structure data
# 56               Not in the pathway
# 57               Not in the pathway
# 58               Not in the pathway
# 59               Not in the pathway
# 60               Not in the pathway
# 61               Not in the pathway
# 62               Not in the pathway
# 63               Not in the pathway
# 64               Not in the pathway
# 65               Not in the pathway
# 66               Not in the pathway
# 67               Not in the pathway
# 68               Not in the pathway
# 69               Not in the pathway
# 70               Not in the pathway
# 71               Not in the pathway
# 72               Not in the pathway
# 73               Not in the pathway
# 74               Not in the pathway
# 75               Not in the pathway
# 76               Not in the pathway
# 77               Not in the pathway
# 78               Not in the pathway
# 79        human disease or disorder

# %%
subset['orig_id'] = subset['orig_dataset'] + ':' + subset['orig_entry']
subset['dest_id'] = subset['dest_dataset'] + ':' + subset['dest_entry']
subset
# Out:
# /tmp/ipykernel_35346/2486089064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['orig_id'] = subset['orig_dataset'] + ':' + subset['orig_entry']
# /tmp/ipykernel_35346/2486089064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['dest_id'] = subset['dest_dataset'] + ':' + subset['dest_entry']
#     orig_dataset       orig_entry orig_label        dest_dataset  \
# 0   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 1   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 2   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 3   ensembl_gene  ENSG00000172915       NBEA  ensembl_transcript
# 4   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 5   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 6   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 7   ensembl_gene  ENSG00000172915       NBEA            ncbigene
# 8   ensembl_gene  ENSG00000172915       NBEA             uniprot
# 9   ensembl_gene  ENSG00000172915       NBEA             uniprot
# 10  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 11  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 12  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 13  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 14  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 15  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 16  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 17  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 18  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 19  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 20  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 21  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 22  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 23  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 24  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 25  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 26  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 27  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 28  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 29  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 30  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 31  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 32  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 33  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 34  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 35  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 36  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 37  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 38  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 39  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 40  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 41  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 42  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 43  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 44  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 45  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 46  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 47  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 48  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 49  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 50  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 51  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 52  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 53  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 54  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 55  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 56  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 57  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 58  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 59  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 60  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 61  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 62  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 63  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 64  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 65  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 66  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 67  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 68  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 69  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 70  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 71  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 72  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 73  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 74  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 75  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 76  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 77  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 78  ensembl_gene  ENSG00000172915       NBEA             uniprot
# 79  ensembl_gene  ENSG00000172915       NBEA               mondo
#
#          dest_entry                                       node  \
# 0   ENST00000379939                 transcript_biotype_ensembl
# 1   ENST00000400445                 transcript_biotype_ensembl
# 2   ENST00000537702                 transcript_biotype_ensembl
# 3   ENST00000629018                 transcript_biotype_ensembl
# 4             26960  gene_evolutionary_conservation_homologene
# 5             26960           gene_molecular_function_ncbigene
# 6             26960           gene_biological_process_ncbigene
# 7             26960           gene_biological_process_ncbigene
# 8        A0A0D9SF28   protein_disease_related_proteins_uniprot
# 9        A0A8I5KQL6   protein_disease_related_proteins_uniprot
# 10       A0A8I5KQP5   protein_disease_related_proteins_uniprot
# 11       A0A8I5KRX1   protein_disease_related_proteins_uniprot
# 12       A0A8I5KRZ1   protein_disease_related_proteins_uniprot
# 13       A0A8I5KS18   protein_disease_related_proteins_uniprot
# 14       A0A8I5KS58   protein_disease_related_proteins_uniprot
# 15       A0A8I5KSX3   protein_disease_related_proteins_uniprot
# 16       A0A8I5KTV6   protein_disease_related_proteins_uniprot
# 17       A0A8I5KTY1   protein_disease_related_proteins_uniprot
# 18       A0A8I5KWL1   protein_disease_related_proteins_uniprot
# 19       A0A8I5KX92   protein_disease_related_proteins_uniprot
# 20       A0A8I5KXL4   protein_disease_related_proteins_uniprot
# 21       A0A8I5KXR7   protein_disease_related_proteins_uniprot
# 22       A0A8I5KXW8   protein_disease_related_proteins_uniprot
# 23       A0A8I5KXY8   protein_disease_related_proteins_uniprot
# 24       A0A8I5KZ13   protein_disease_related_proteins_uniprot
# 25       A0A8I5QJB2   protein_disease_related_proteins_uniprot
# 26       A0A8I5QJQ0   protein_disease_related_proteins_uniprot
# 27       A0A8I5QKR1   protein_disease_related_proteins_uniprot
# 28       A0A8I5QKR6   protein_disease_related_proteins_uniprot
# 29           Q5T321   protein_disease_related_proteins_uniprot
# 30           Q8NFP9   protein_disease_related_proteins_uniprot
# 31           Q8NFP9   protein_disease_related_proteins_uniprot
# 32           Q8NFP9   protein_disease_related_proteins_uniprot
# 33       A0A0D9SF28           structure_data_existence_uniprot
# 34       A0A8I5KQL6           structure_data_existence_uniprot
# 35       A0A8I5KQP5           structure_data_existence_uniprot
# 36       A0A8I5KRX1           structure_data_existence_uniprot
# 37       A0A8I5KRZ1           structure_data_existence_uniprot
# 38       A0A8I5KS18           structure_data_existence_uniprot
# 39       A0A8I5KS58           structure_data_existence_uniprot
# 40       A0A8I5KSX3           structure_data_existence_uniprot
# 41       A0A8I5KTV6           structure_data_existence_uniprot
# 42       A0A8I5KTY1           structure_data_existence_uniprot
# 43       A0A8I5KWL1           structure_data_existence_uniprot
# 44       A0A8I5KX92           structure_data_existence_uniprot
# 45       A0A8I5KXL4           structure_data_existence_uniprot
# 46       A0A8I5KXR7           structure_data_existence_uniprot
# 47       A0A8I5KXW8           structure_data_existence_uniprot
# 48       A0A8I5KXY8           structure_data_existence_uniprot
# 49       A0A8I5KZ13           structure_data_existence_uniprot
# 50       A0A8I5QJB2           structure_data_existence_uniprot
# 51       A0A8I5QJQ0           structure_data_existence_uniprot
# 52       A0A8I5QKR1           structure_data_existence_uniprot
# 53       A0A8I5QKR6           structure_data_existence_uniprot
# 54           Q5T321           structure_data_existence_uniprot
# 55           Q8NFP9           structure_data_existence_uniprot
# 56       A0A0D9SF28   interaction_proteins_in_pathway_reactome
# 57       A0A8I5KQL6   interaction_proteins_in_pathway_reactome
# 58       A0A8I5KQP5   interaction_proteins_in_pathway_reactome
# 59       A0A8I5KRX1   interaction_proteins_in_pathway_reactome
# 60       A0A8I5KRZ1   interaction_proteins_in_pathway_reactome
# 61       A0A8I5KS18   interaction_proteins_in_pathway_reactome
# 62       A0A8I5KS58   interaction_proteins_in_pathway_reactome
# 63       A0A8I5KSX3   interaction_proteins_in_pathway_reactome
# 64       A0A8I5KTV6   interaction_proteins_in_pathway_reactome
# 65       A0A8I5KTY1   interaction_proteins_in_pathway_reactome
# 66       A0A8I5KWL1   interaction_proteins_in_pathway_reactome
# 67       A0A8I5KX92   interaction_proteins_in_pathway_reactome
# 68       A0A8I5KXL4   interaction_proteins_in_pathway_reactome
# 69       A0A8I5KXR7   interaction_proteins_in_pathway_reactome
# 70       A0A8I5KXW8   interaction_proteins_in_pathway_reactome
# 71       A0A8I5KXY8   interaction_proteins_in_pathway_reactome
# 72       A0A8I5KZ13   interaction_proteins_in_pathway_reactome
# 73       A0A8I5QJB2   interaction_proteins_in_pathway_reactome
# 74       A0A8I5QJQ0   interaction_proteins_in_pathway_reactome
# 75       A0A8I5QKR1   interaction_proteins_in_pathway_reactome
# 76       A0A8I5QKR6   interaction_proteins_in_pathway_reactome
# 77           Q5T321   interaction_proteins_in_pathway_reactome
# 78           Q8NFP9   interaction_proteins_in_pathway_reactome
# 79          0030930                     disease_diseases_mondo
#
#                               value                       orig_id  \
# 0                    protein coding  ensembl_gene:ENSG00000172915
# 1                    protein coding  ensembl_gene:ENSG00000172915
# 2                    protein coding  ensembl_gene:ENSG00000172915
# 3                    protein coding  ensembl_gene:ENSG00000172915
# 4                      Insect, Worm  ensembl_gene:ENSG00000172915
# 5                           binding  ensembl_gene:ENSG00000172915
# 6                  cellular process  ensembl_gene:ENSG00000172915
# 7                      localization  ensembl_gene:ENSG00000172915
# 8                      Unclassified  ensembl_gene:ENSG00000172915
# 9                      Unclassified  ensembl_gene:ENSG00000172915
# 10                     Unclassified  ensembl_gene:ENSG00000172915
# 11                     Unclassified  ensembl_gene:ENSG00000172915
# 12                     Unclassified  ensembl_gene:ENSG00000172915
# 13                     Unclassified  ensembl_gene:ENSG00000172915
# 14                     Unclassified  ensembl_gene:ENSG00000172915
# 15                     Unclassified  ensembl_gene:ENSG00000172915
# 16                     Unclassified  ensembl_gene:ENSG00000172915
# 17                     Unclassified  ensembl_gene:ENSG00000172915
# 18                     Unclassified  ensembl_gene:ENSG00000172915
# 19                     Unclassified  ensembl_gene:ENSG00000172915
# 20                     Unclassified  ensembl_gene:ENSG00000172915
# 21                     Unclassified  ensembl_gene:ENSG00000172915
# 22                     Unclassified  ensembl_gene:ENSG00000172915
# 23                     Unclassified  ensembl_gene:ENSG00000172915
# 24                     Unclassified  ensembl_gene:ENSG00000172915
# 25                     Unclassified  ensembl_gene:ENSG00000172915
# 26                     Unclassified  ensembl_gene:ENSG00000172915
# 27                     Unclassified  ensembl_gene:ENSG00000172915
# 28                     Unclassified  ensembl_gene:ENSG00000172915
# 29                     Unclassified  ensembl_gene:ENSG00000172915
# 30          Intellectual disability  ensembl_gene:ENSG00000172915
# 31                  Disease variant  ensembl_gene:ENSG00000172915
# 32                         Epilepsy  ensembl_gene:ENSG00000172915
# 33  Proteins without structure data  ensembl_gene:ENSG00000172915
# 34  Proteins without structure data  ensembl_gene:ENSG00000172915
# 35  Proteins without structure data  ensembl_gene:ENSG00000172915
# 36  Proteins without structure data  ensembl_gene:ENSG00000172915
# 37  Proteins without structure data  ensembl_gene:ENSG00000172915
# 38  Proteins without structure data  ensembl_gene:ENSG00000172915
# 39  Proteins without structure data  ensembl_gene:ENSG00000172915
# 40  Proteins without structure data  ensembl_gene:ENSG00000172915
# 41  Proteins without structure data  ensembl_gene:ENSG00000172915
# 42  Proteins without structure data  ensembl_gene:ENSG00000172915
# 43  Proteins without structure data  ensembl_gene:ENSG00000172915
# 44  Proteins without structure data  ensembl_gene:ENSG00000172915
# 45  Proteins without structure data  ensembl_gene:ENSG00000172915
# 46  Proteins without structure data  ensembl_gene:ENSG00000172915
# 47  Proteins without structure data  ensembl_gene:ENSG00000172915
# 48  Proteins without structure data  ensembl_gene:ENSG00000172915
# 49  Proteins without structure data  ensembl_gene:ENSG00000172915
# 50  Proteins without structure data  ensembl_gene:ENSG00000172915
# 51  Proteins without structure data  ensembl_gene:ENSG00000172915
# 52  Proteins without structure data  ensembl_gene:ENSG00000172915
# 53  Proteins without structure data  ensembl_gene:ENSG00000172915
# 54  Proteins without structure data  ensembl_gene:ENSG00000172915
# 55     Proteins with structure data  ensembl_gene:ENSG00000172915
# 56               Not in the pathway  ensembl_gene:ENSG00000172915
# 57               Not in the pathway  ensembl_gene:ENSG00000172915
# 58               Not in the pathway  ensembl_gene:ENSG00000172915
# 59               Not in the pathway  ensembl_gene:ENSG00000172915
# 60               Not in the pathway  ensembl_gene:ENSG00000172915
# 61               Not in the pathway  ensembl_gene:ENSG00000172915
# 62               Not in the pathway  ensembl_gene:ENSG00000172915
# 63               Not in the pathway  ensembl_gene:ENSG00000172915
# 64               Not in the pathway  ensembl_gene:ENSG00000172915
# 65               Not in the pathway  ensembl_gene:ENSG00000172915
# 66               Not in the pathway  ensembl_gene:ENSG00000172915
# 67               Not in the pathway  ensembl_gene:ENSG00000172915
# 68               Not in the pathway  ensembl_gene:ENSG00000172915
# 69               Not in the pathway  ensembl_gene:ENSG00000172915
# 70               Not in the pathway  ensembl_gene:ENSG00000172915
# 71               Not in the pathway  ensembl_gene:ENSG00000172915
# 72               Not in the pathway  ensembl_gene:ENSG00000172915
# 73               Not in the pathway  ensembl_gene:ENSG00000172915
# 74               Not in the pathway  ensembl_gene:ENSG00000172915
# 75               Not in the pathway  ensembl_gene:ENSG00000172915
# 76               Not in the pathway  ensembl_gene:ENSG00000172915
# 77               Not in the pathway  ensembl_gene:ENSG00000172915
# 78               Not in the pathway  ensembl_gene:ENSG00000172915
# 79        human disease or disorder  ensembl_gene:ENSG00000172915
#
#                                dest_id
# 0   ensembl_transcript:ENST00000379939
# 1   ensembl_transcript:ENST00000400445
# 2   ensembl_transcript:ENST00000537702
# 3   ensembl_transcript:ENST00000629018
# 4                       ncbigene:26960
# 5                       ncbigene:26960
# 6                       ncbigene:26960
# 7                       ncbigene:26960
# 8                   uniprot:A0A0D9SF28
# 9                   uniprot:A0A8I5KQL6
# 10                  uniprot:A0A8I5KQP5
# 11                  uniprot:A0A8I5KRX1
# 12                  uniprot:A0A8I5KRZ1
# 13                  uniprot:A0A8I5KS18
# 14                  uniprot:A0A8I5KS58
# 15                  uniprot:A0A8I5KSX3
# 16                  uniprot:A0A8I5KTV6
# 17                  uniprot:A0A8I5KTY1
# 18                  uniprot:A0A8I5KWL1
# 19                  uniprot:A0A8I5KX92
# 20                  uniprot:A0A8I5KXL4
# 21                  uniprot:A0A8I5KXR7
# 22                  uniprot:A0A8I5KXW8
# 23                  uniprot:A0A8I5KXY8
# 24                  uniprot:A0A8I5KZ13
# 25                  uniprot:A0A8I5QJB2
# 26                  uniprot:A0A8I5QJQ0
# 27                  uniprot:A0A8I5QKR1
# 28                  uniprot:A0A8I5QKR6
# 29                      uniprot:Q5T321
# 30                      uniprot:Q8NFP9
# 31                      uniprot:Q8NFP9
# 32                      uniprot:Q8NFP9
# 33                  uniprot:A0A0D9SF28
# 34                  uniprot:A0A8I5KQL6
# 35                  uniprot:A0A8I5KQP5
# 36                  uniprot:A0A8I5KRX1
# 37                  uniprot:A0A8I5KRZ1
# 38                  uniprot:A0A8I5KS18
# 39                  uniprot:A0A8I5KS58
# 40                  uniprot:A0A8I5KSX3
# 41                  uniprot:A0A8I5KTV6
# 42                  uniprot:A0A8I5KTY1
# 43                  uniprot:A0A8I5KWL1
# 44                  uniprot:A0A8I5KX92
# 45                  uniprot:A0A8I5KXL4
# 46                  uniprot:A0A8I5KXR7
# 47                  uniprot:A0A8I5KXW8
# 48                  uniprot:A0A8I5KXY8
# 49                  uniprot:A0A8I5KZ13
# 50                  uniprot:A0A8I5QJB2
# 51                  uniprot:A0A8I5QJQ0
# 52                  uniprot:A0A8I5QKR1
# 53                  uniprot:A0A8I5QKR6
# 54                      uniprot:Q5T321
# 55                      uniprot:Q8NFP9
# 56                  uniprot:A0A0D9SF28
# 57                  uniprot:A0A8I5KQL6
# 58                  uniprot:A0A8I5KQP5
# 59                  uniprot:A0A8I5KRX1
# 60                  uniprot:A0A8I5KRZ1
# 61                  uniprot:A0A8I5KS18
# 62                  uniprot:A0A8I5KS58
# 63                  uniprot:A0A8I5KSX3
# 64                  uniprot:A0A8I5KTV6
# 65                  uniprot:A0A8I5KTY1
# 66                  uniprot:A0A8I5KWL1
# 67                  uniprot:A0A8I5KX92
# 68                  uniprot:A0A8I5KXL4
# 69                  uniprot:A0A8I5KXR7
# 70                  uniprot:A0A8I5KXW8
# 71                  uniprot:A0A8I5KXY8
# 72                  uniprot:A0A8I5KZ13
# 73                  uniprot:A0A8I5QJB2
# 74                  uniprot:A0A8I5QJQ0
# 75                  uniprot:A0A8I5QKR1
# 76                  uniprot:A0A8I5QKR6
# 77                      uniprot:Q5T321
# 78                      uniprot:Q8NFP9
# 79                       mondo:0030930

# %%
id_pairs = subset[['orig_id', 'dest_id']].drop_duplicates()
id_pairs = id_pairs[id_pairs['orig_id'] != id_pairs['dest_id']]
id_pairs
# Out:
#                          orig_id                             dest_id
# 0   ensembl_gene:ENSG00000172915  ensembl_transcript:ENST00000379939
# 1   ensembl_gene:ENSG00000172915  ensembl_transcript:ENST00000400445
# 2   ensembl_gene:ENSG00000172915  ensembl_transcript:ENST00000537702
# 3   ensembl_gene:ENSG00000172915  ensembl_transcript:ENST00000629018
# 4   ensembl_gene:ENSG00000172915                      ncbigene:26960
# 8   ensembl_gene:ENSG00000172915                  uniprot:A0A0D9SF28
# 9   ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KQL6
# 10  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KQP5
# 11  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KRX1
# 12  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KRZ1
# 13  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KS18
# 14  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KS58
# 15  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KSX3
# 16  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KTV6
# 17  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KTY1
# 18  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KWL1
# 19  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KX92
# 20  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KXL4
# 21  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KXR7
# 22  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KXW8
# 23  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KXY8
# 24  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5KZ13
# 25  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5QJB2
# 26  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5QJQ0
# 27  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5QKR1
# 28  ensembl_gene:ENSG00000172915                  uniprot:A0A8I5QKR6
# 29  ensembl_gene:ENSG00000172915                      uniprot:Q5T321
# 30  ensembl_gene:ENSG00000172915                      uniprot:Q8NFP9
# 79  ensembl_gene:ENSG00000172915                       mondo:0030930

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Configuration

# %%
categories_color = {
  "Analysis": { "color": "#696969" },
  "Compound": { "color": "#a853c6" },
  "Disease": { "color": "#5361c6" },
  "Domain": { "color": "#a2c653" },
  "Experiment": { "color": "#696969" },
  "Function": { "color": "#696969" },
  "Gene": { "color": "#53c666" },
  "Glycan": { "color": "#673aa6" },
  "Interaction": { "color": "#c65381" },
  "Literature": { "color": "#696969" },
  "Ortholog": { "color": "#53c666" },
  "Pathway": { "color": "#c65381" },
  "Probe": { "color": "#53c666" },
  "Project": { "color": "#696969" },
  "Protein": { "color": "#a2c653" },
  "Reaction": { "color": "#c65381" },
  "Sample": { "color": "#696969" },
  "SequenceRun": { "color": "#696969" },
  "Structure": { "color": "#c68753" },
  "Submission": { "color": "#696969" },
  "Taxonomy": { "color": "#006400" },
  "Transcript": { "color": "#53c666" },
  "Variant": { "color": "#53c3c6" },
};

# %%
attributes_json_url = 'https://github.com/togodx/togodx-config-human/raw/develop/config/attributes.dx-server.json'
attributes_json = json.loads(urlopen(attributes_json_url).read())
attributes_json
# Out:
# {'categories': [{'id': 'gene',
#    'label': 'Gene',
#    'attributes': ['gene_biotype_ensembl',
#     'gene_chromosome_ensembl',
#     'gene_number_of_paralogs_homologene',
#     'gene_ortholog_existence_homologene',
#     'gene_evolutionary_conservation_homologene',
#     'gene_biological_process_ncbigene',
#     'gene_cellular_component_ncbigene',
#     'gene_molecular_function_ncbigene',
#     'gene_high_level_expression_refex',
#     'gene_low_level_expression_refex',
#     'gene_high_level_expression_gtex6',
#     'gene_not_expressed_in_tissues_gtex',
#     'gene_specific_expression_in_tissues_hpa',
#     'gene_specific_expression_in_cells_hpa',
#     'transcript_biotype_ensembl',
#     'transcript_length_ensembl']},
#   {'id': 'protein',
#    'label': 'Protein',
#    'attributes': ['protein_uniprotkb_section_uniprot',
#     'protein_domains_uniprot',
#     'protein_biological_process_uniprot',
#     'protein_cellular_component_uniprot',
#     'protein_molecular_function_uniprot',
#     'protein_isoform_specific_go_existence_nextprot',
#     'protein_ligands_uniprot',
#     'protein_molecular_mass_uniprot',
#     'protein_ptms_uniprot',
#     'protein_catalytic_activity_uniprot',
#     'protein_number_of_transmembrane_domains_uniprot',
#     'protein_number_of_phosphorylation_sites_uniprot',
#     'protein_number_of_glycosylation_sites_uniprot',
#     'protein_disease_related_proteins_uniprot',
#     'protein_isolation_source_uniprot',
#     'protein_evidence_of_existence_nextprot',
#     'protein_isoform_specific_interaction_existence_nextprot',
#     'protein_pathway_annotation_uniprot']},
#   {'id': 'structure',
#    'label': 'Structure',
#    'attributes': ['structure_data_existence_uniprot',
#     'structure_helical_regions_uniprot',
#     'structure_beta_strand_regions_uniprot',
#     'structure_number_of_turns_uniprot',
#     'structure_number_of_disulfide_bonds_uniprot',
#     'structure_disorder_annotation_uniprot',
#     'structure_number_of_peptides_pdb',
#     'structure_analysis_methods_pdb']},
#   {'id': 'interaction',
#    'label': 'Interaction',
#    'attributes': ['interaction_proteins_in_pathway_reactome',
#     'interaction_compounds_in_pathway_reactome',
#     'interaction_number_of_interacting_proteins_uniprot',
#     'interaction_chembl_assay_existence_uniprot']},
#   {'id': 'compound',
#    'label': 'Compound',
#    'attributes': ['compound_chemical_role_chebi',
#     'compound_application_type_chebi',
#     'compound_action_type_chembl',
#     'compound_biological_role_chebi',
#     'compound_drug_indication_mesh_chembl',
#     'compound_drug_development_phase_chembl',
#     'compound_atc_classification_pubchem',
#     'compound_atc_classification_chembl']},
#   {'id': 'glycan',
#    'label': 'Glycan',
#    'attributes': ['glycan_mass_glycosmos',
#     'glycan_tissue_glycosmos',
#     'glycan_subsumption_glycosmos']},
#   {'id': 'disease',
#    'label': 'Disease',
#    'attributes': ['disease_diseases_mondo',
#     'disease_diseases_mesh',
#     'disease_diseases_nando',
#     'disease_related_dbs_mondo',
#     'disease_phenotypic_abnormality_hpo']},
#   {'id': 'variant',
#    'label': 'Variant',
#    'attributes': ['variant_gwas_togovar',
#     'variant_clinical_significance_togovar']}],
#  'attributes': {'gene_biotype_ensembl': {'label': 'Gene biotype',
#    'description': 'Gene classification annotated in Ensembl',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_biotype_ensembl',
#    'order': 'numerical_desc',
#    'dataset': 'ensembl_gene',
#    'datamodel': 'classification',
#    'source': [{'label': 'Ensembl',
#      'url': 'http://nov2020.archive.ensembl.org/Homo_sapiens/Info/Index',
#      'version': 'human release 108',
#      'updated': '2022-10-22'}]},
#   'gene_chromosome_ensembl': {'label': 'Chromosome',
#    'description': 'Chromosome where a gene is located',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_chromosome_ensembl',
#    'order': 'id_asc',
#    'dataset': 'ensembl_gene',
#    'datamodel': 'classification',
#    'source': [{'label': 'Ensembl',
#      'url': 'http://nov2020.archive.ensembl.org/Homo_sapiens/Info/Index',
#      'version': 'human release 108',
#      'updated': '2022-10-22'}]},
#   'gene_number_of_paralogs_homologene': {'label': '# of paralogs',
#    'description': 'Number of duplicated genes (paralogs) in each human gene calculated based on HomoloGene',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_number_of_paralogs_homologene',
#    'order': 'id_asc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'HomoloGene',
#      'url': 'https://www.ncbi.nlm.nih.gov/homologene/statistics/',
#      'version': 'Release 68',
#      'updated': '2021-03-12'}]},
#   'gene_ortholog_existence_homologene': {'label': 'Ortholog existence',
#    'description': 'Ortholog existence for each human gene in other organisms defined by HomoloGene',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_ortholog_existence_homologene',
#    'order': 'id_asc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'HomoloGene',
#      'url': 'https://www.ncbi.nlm.nih.gov/homologene/statistics/',
#      'version': 'Release 68',
#      'updated': '2021-03-12'}]},
#   'gene_evolutionary_conservation_homologene': {'label': 'Evolutionary divergence',
#    'description': 'Most distant organisms from human that have orthologous genes in HomoloGene',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_evolutionary_conservation_homologene',
#    'order': 'id_asc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'HomoloGene',
#      'url': 'https://www.ncbi.nlm.nih.gov/homologene/statistics/',
#      'version': 'Release 68',
#      'updated': '2021-03-12'}]},
#   'gene_biological_process_ncbigene': {'label': 'Biological process',
#    'description': 'Functional annotations (GO terms) derived from the Biological process category of Gene Ontology, which GOA has assigned to each human gene with evidence information',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_biological_process_ncbigene',
#    'order': 'numerical_desc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'NCBI Gene',
#      'url': 'https://ftp.ncbi.nlm.nih.gov/gene/DATA/',
#      'version': 'N/A',
#      'updated': '2022-05-25'}]},
#   'gene_cellular_component_ncbigene': {'label': 'Cellular component',
#    'description': 'Functional annotations (GO terms) derived from the Cellular component category of Gene Ontology, which GOA has assigned to each human gene with evidence information',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_cellular_component_ncbigene',
#    'order': 'numerical_desc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'NCBI Gene',
#      'url': 'https://ftp.ncbi.nlm.nih.gov/gene/DATA/',
#      'version': 'N/A',
#      'updated': '2022-05-25'}]},
#   'gene_molecular_function_ncbigene': {'label': 'Molecular function',
#    'description': 'Functional annotations (GO terms) derived from the Molecular function category of Gene Ontology, which GOA has assigned to each human gene with evidence information',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_molecular_function_ncbigene',
#    'order': 'numerical_desc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'NCBI Gene',
#      'url': 'https://ftp.ncbi.nlm.nih.gov/gene/DATA/',
#      'version': 'N/A',
#      'updated': '2022-05-25'}]},
#   'gene_high_level_expression_refex': {'label': 'Tissue-specific high expression (RefEx GeneChip)',
#    'description': 'Tissues in which a gene was tissue-specific highly expressed in 34 tissues of RefEx(GeneChip microarray)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_high_level_expression_refex',
#    'order': 'numerical_desc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'Calculations for tissue specificity of genechip human GSE7307 from RefEx',
#      'url': 'https://doi.org/10.6084/m9.figshare.4028700.v3',
#      'version': 'N/A',
#      'updated': '2021-03-12'}]},
#   'gene_low_level_expression_refex': {'label': 'Tissue-specific low expression (RefEx GeneChip)',
#    'description': 'Tissues in which a gene was tissue-specific lowly expressed in 34 tissues of RefEx(GeneChip microarray)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_low_level_expression_refex',
#    'order': 'numerical_desc',
#    'dataset': 'ncbigene',
#    'datamodel': 'classification',
#    'source': [{'label': 'Calculations for tissue specificity of genechip human GSE7307 from RefEx',
#      'url': 'https://doi.org/10.6084/m9.figshare.4028700.v3',
#      'version': 'N/A',
#      'updated': '2021-03-12'}]},
#   'gene_high_level_expression_gtex6': {'label': 'Tissue-specific high expression (GTEx)',
#    'description': 'Tissues in which a gene is tissue-specific highly expressed in 49 tissues of GTEx V6',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_high_level_expression_gtex6',
#    'order': 'numerical_desc',
#    'dataset': 'ensembl_gene',
#    'datamodel': 'classification',
#    'source': [{'label': 'GTEx',
#      'url': 'https://doi.org/10.1101/311563',
#      'version': 'V6',
#      'updated': '2018-04-30'}]},
#   'gene_not_expressed_in_tissues_gtex': {'label': 'No expression in tissues (GTEx)',
#    'description': 'Tissues in which expression of a gene is not detected in 53 tissues of GTEx V8',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_not_expressed_in_tissues_gtex',
#    'order': 'numerical_desc',
#    'dataset': 'ensembl_gene',
#    'datamodel': 'classification',
#    'source': [{'label': 'GTEx',
#      'url': 'https://gtexportal.org/home/datasets',
#      'version': 'Release V8',
#      'updated': '2019-08-26'}]},
#   'gene_specific_expression_in_tissues_hpa': {'label': 'Tissue-specific high expression (HPA)',
#    'description': 'Tissues in which expression specificity of a gene is evaluated as "Tissue enriched", "Tissue enhanced", or "Group enriched" by Human Protein Atlas',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_specific_expression_in_tissues_hpa',
#    'order': 'numerical_desc',
#    'dataset': 'ensembl_gene',
#    'datamodel': 'classification',
#    'source': [{'label': 'HPA (Data from the Human Protein Atlas in tab-separated format)',
#      'url': 'https://www.proteinatlas.org/about/download',
#      'version': 'V20',
#      'updated': '2020-11-19'}]},
#   'gene_specific_expression_in_cells_hpa': {'label': 'Cell type-specific high expression (HPA)',
#    'description': 'Cell types in which expression specificity of a gene is evaluated as "Cell type enriched", "Cell type enhanced", or "Group enriched" by Human Protein Atlas',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/gene_specific_expression_in_cells_hpa',
#    'order': 'numerical_desc',
#    'dataset': 'ensembl_gene',
#    'datamodel': 'classification',
#    'source': [{'label': 'HPA (Data from the Human Protein Atlas in tab-separated format)',
#      'url': 'https://www.proteinatlas.org/about/download',
#      'version': 'V20',
#      'updated': '2020-11-19'}]},
#   'transcript_biotype_ensembl': {'label': 'Transcript biotype',
#    'description': 'Transcript classification annotated in Ensembl',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/transcript_biotype_ensembl',
#    'order': 'numerical_desc',
#    'dataset': 'ensembl_transcript',
#    'datamodel': 'classification',
#    'source': [{'label': 'Ensembl',
#      'url': 'http://nov2020.archive.ensembl.org/Homo_sapiens/Info/Index',
#      'version': 'human release 108',
#      'updated': '2022-10-22'}]},
#   'transcript_length_ensembl': {'label': 'Transcript length',
#    'description': 'Transcript length (bp) based on Ensembl',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/transcript_length_ensembl',
#    'dataset': 'ensembl_transcript',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Ensembl',
#      'url': 'http://nov2020.archive.ensembl.org/Homo_sapiens/Info/Index',
#      'version': 'human release 108',
#      'updated': '2022-10-22'}]},
#   'protein_uniprotkb_section_uniprot': {'label': 'UniProtKB sections',
#    'description': 'Protein sections consisting of manually annotated UniProtKB/Swiss-Prot and automatically annotated UniProtKB/TrEMBL',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_uniprotkb_section_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_domains_uniprot': {'label': 'Protein domains',
#    'description': 'Protein domains from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_domains_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_biological_process_uniprot': {'label': 'Biological process',
#    'description': 'Functional annotations (GO terms) derived from the Biological process category of GeneOntology, which Uniprot has assigned to each human protein with evidence information',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_biological_process_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Gene ontology biological process annotation from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_cellular_component_uniprot': {'label': 'Cellular component',
#    'description': 'Functional annotations (GO terms) derived from the Cellular component category of GeneOntology, which Uniprot has assigned to each human protein with evidence information',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_cellular_component_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Gene ontology cellular component annotation from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_molecular_function_uniprot': {'label': 'Molecular function',
#    'description': 'Functional annotations (GO terms) derived from the Molecular function category of GeneOntology, which Uniprot has assigned to each human protein with evidence information',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_molecular_function_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Gene ontology molecular function annotation from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_isoform_specific_go_existence_nextprot': {'label': 'Isoform specific go existence',
#    'description': 'GO classification of proteins with isoform-specific GO annotations from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_isoform_specific_go_existence_nextprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Isoform SPECIFIC annotation from neXtProt',
#      'url': 'https://www.nextprot.org/',
#      'version': 'Release 2022-08-18',
#      'updated': '2022-08-18'}]},
#   'protein_ligands_uniprot': {'label': 'Ligands',
#    'description': 'Classification by non-protein molecules which bind/react with proteins in Function section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_ligands_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Function from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_molecular_mass_uniprot': {'label': 'Molecular mass',
#    'description': 'Molecular weight of the protein including information from multiple isoforms in Sequences section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_molecular_mass_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Sequences from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_ptms_uniprot': {'label': 'PTMs',
#    'description': 'Classification by types of post-translational modifications, including S-S bonds (disulfide bonds) in Amino acid modifications section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_ptms_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Amino acid modifications from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_catalytic_activity_uniprot': {'label': 'Catalytic activity',
#    'description': 'Classification by catalytic activity, based on the Enzyme Committee (EC) number',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_catalytic_activity_uniprot',
#    'order': 'id_asc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Catalytic activity from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_number_of_transmembrane_domains_uniprot': {'label': '# of transmembrane domains',
#    'description': 'Number of transmembrane domains. A group of molecules forming a family, such as channels, may have the same number of domains in Topology section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_number_of_transmembrane_domains_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Topology from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_number_of_phosphorylation_sites_uniprot': {'label': '# of phosphorylation sites',
#    'description': 'Number of phosphorylation at Ser/Thr/Tyr, which may create an activation state for the protein and acts like a switch in Amino acid modifications section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_number_of_phosphorylation_sites_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Amino acid modifications from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_number_of_glycosylation_sites_uniprot': {'label': '# of glycosylation sites',
#    'description': 'Number of glycosylation sites, including N-linked,O-linked and others in Amino acid modifications section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_number_of_glycosylation_sites_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Amino acid modifications from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_disease_related_proteins_uniprot': {'label': 'Disease-related proteins',
#    'description': 'Disease-related proteins in Pathology & Biotech section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_disease_related_proteins_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Pathology & Biotech from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_isolation_source_uniprot': {'label': 'Tissues w/expression reported',
#    'description': 'Classification based on the name of the tissue from which the clone was isolated in the reference describing the protein sequence in Tissue section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_isolation_source_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Tissue from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'protein_evidence_of_existence_nextprot': {'label': 'Evidence of existence',
#    'description': 'Classification by the basis of protein expression, such as whether it has been identified as a protein or transcript in Expression section from neXtProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_evidence_of_existence_nextprot',
#    'order': 'id_asc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Expression from neXtProt',
#      'url': 'https://www.nextprot.org/',
#      'version': 'Release 2022-08-18',
#      'updated': '2022-08-18'}]},
#   'protein_isoform_specific_interaction_existence_nextprot': {'label': 'Isoform specific interaction existence',
#    'description': 'Proteins with isoform-specific PPI annotations from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_isoform_specific_interaction_existence_nextprot',
#    'order': 'id_asc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Isoform SPECIFIC annotation from neXtProt',
#      'url': 'https://www.nextprot.org/',
#      'version': 'Release 2022-08-18',
#      'updated': '2022-08-18'}]},
#   'protein_pathway_annotation_uniprot': {'label': 'Pathway annotation',
#    'description': 'Classification by reaction, based on Uniprot pathways',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/protein_pathway_annotation_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Pathway from UniProt',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_data_existence_uniprot': {'label': 'Structure data existence',
#    'description': 'Uniprot entries having 3D structure data in PDB in Structure section from Uniprot',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_data_existence_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Structure from Uniprot',
#      'url': 'https://www.uniprot.org/help/structure_section',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_helical_regions_uniprot': {'label': 'Rate of helical regions',
#    'description': 'Rate of helical regions in each entry of UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_helical_regions_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Structure from Uniprot',
#      'url': 'https://www.uniprot.org/help/helix',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_beta_strand_regions_uniprot': {'label': 'Rate of beta strand regions',
#    'description': 'Rate of beta strand regions in each entry of UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_beta_strand_regions_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Structure from Uniprot',
#      'url': 'https://www.uniprot.org/help/strand',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_number_of_turns_uniprot': {'label': '# of turn structures',
#    'description': 'Number of turn structures from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_number_of_turns_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Structure from Uniprot',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_number_of_disulfide_bonds_uniprot': {'label': '# of disulfide bonds',
#    'description': 'Number of disulfide bounds from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_number_of_disulfide_bonds_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Structure from Uniprot',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_disorder_annotation_uniprot': {'label': 'Rate of disorder regions',
#    'description': 'Rate of disorder regions in each entry of UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_disorder_annotation_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Structure from Uniprot',
#      'url': 'https://www.uniprot.org/',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'structure_number_of_peptides_pdb': {'label': '# of peptides in a PDB entry',
#    'description': 'The number of peptides in a PDB entry',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_number_of_peptides_pdb',
#    'dataset': 'pdb',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Entity from PDB',
#      'url': 'https://data.pdbj.org/pdbjplus/data/pdb/rdf/',
#      'version': 'N/A',
#      'updated': '2022-12-14'}]},
#   'structure_analysis_methods_pdb': {'label': 'Analysis methods',
#    'description': 'Classification by the method used to determine the three-dimensional structure in Experimental method section from PDB',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/structure_analysis_methods_pdb',
#    'order': 'numerical_desc',
#    'dataset': 'pdb',
#    'datamodel': 'classification',
#    'source': [{'label': 'Experimental method from PDB',
#      'url': 'https://data.pdbj.org/pdbjplus/data/pdb/rdf/',
#      'version': 'N/A',
#      'updated': '2022-12-14'}]},
#   'interaction_proteins_in_pathway_reactome': {'label': 'Proteins in pathway',
#    'description': 'Proteins participating as components classified by pathway (reaction) from Reactome',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/interaction_proteins_in_pathway_reactome',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Reactome',
#      'url': 'https://reactome.org/download-data',
#      'version': '76',
#      'updated': '2021-03-05'}]},
#   'interaction_compounds_in_pathway_reactome': {'label': 'Compounds in pathway',
#    'description': 'Compounds participating as components classified by pathway (reaction) from Reactome',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/interaction_compounds_in_pathway_reactome',
#    'order': 'numerical_desc',
#    'dataset': 'chebi',
#    'datamodel': 'classification',
#    'source': [{'label': 'Reactome',
#      'url': 'https://reactome.org/download-data',
#      'version': '76',
#      'updated': '2021-03-05'}]},
#   'interaction_number_of_interacting_proteins_uniprot': {'label': '# of interacting proteins',
#    'description': 'Classification of uniprot proteins by the number of target proteins they interact with in Interaction section from UniProt',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/interaction_number_of_interacting_proteins_uniprot',
#    'dataset': 'uniprot',
#    'datamodel': 'distribution',
#    'source': [{'label': 'Interaction from UniProt',
#      'url': 'https://www.uniprot.org/help/interaction_section',
#      'version': 'release 2022_05',
#      'updated': '2022-12-14'}]},
#   'interaction_chembl_assay_existence_uniprot': {'label': 'ChEMBL assay existence',
#    'description': 'Uniprot entries classified according to the presence or absence of a method to detect direct protein-compound interactions (ChEMBL assay)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/interaction_chembl_assay_existence_uniprot',
#    'order': 'numerical_desc',
#    'dataset': 'uniprot',
#    'datamodel': 'classification',
#    'source': [{'label': 'Target protein from ChEMBL-RDF against all UniProt entries',
#      'url': 'http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBL-RDF/',
#      'version': 'CHEMBL31',
#      'updated': '2022-08-15'}]},
#   'compound_chemical_role_chebi': {'label': 'Chemical role',
#    'description': 'Classification based on the chemical roles, such as antioxidant or environmental contaminant from ChEBI',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_chemical_role_chebi',
#    'order': 'numerical_desc',
#    'dataset': 'chebi',
#    'datamodel': 'classification',
#    'source': [{'label': 'Chemical role from ChEBI',
#      'url': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:51086',
#      'version': 'Release 220',
#      'updated': '2022-12-01'}]},
#   'compound_application_type_chebi': {'label': 'Application type',
#    'description': 'Classification based on the application types, such as pharmaceutical or pesticide from ChEBI',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_application_type_chebi',
#    'order': 'numerical_desc',
#    'dataset': 'chebi',
#    'datamodel': 'classification',
#    'source': [{'label': 'Application type from ChEBI',
#      'url': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:33232',
#      'version': 'Release 220',
#      'updated': '2022-12-01'}]},
#   'compound_action_type_chembl': {'label': 'Action type',
#    'description': 'Classification based on the mechanism of action, such as an inhibitor or an antagonist from ChEMBL',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_action_type_chembl',
#    'order': 'numerical_desc',
#    'dataset': 'chembl_compound',
#    'datamodel': 'classification',
#    'source': [{'label': 'ChEMBL-RDF',
#      'url': 'http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBL-RDF/',
#      'version': 'CHEMBL31',
#      'updated': '2022-08-15'}]},
#   'compound_biological_role_chebi': {'label': 'Biological role',
#    'description': 'Classification based on the biological roles, such as inhibitor or antimicrobial agent from ChEBI',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_biological_role_chebi',
#    'order': 'numerical_desc',
#    'dataset': 'chebi',
#    'datamodel': 'classification',
#    'source': [{'label': 'Biological role from ChEBI ',
#      'url': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:24432',
#      'version': 'Release 220',
#      'updated': '2022-12-01'}]},
#   'compound_drug_indication_mesh_chembl': {'label': 'Drug indication',
#    'description': 'Classification of diseases for which drugs are indicated, based on hierarchical data using MeSH, a life science thesaurus from ChEMBL',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_drug_indication_mesh_chembl',
#    'order': 'numerical_desc',
#    'dataset': 'chembl_compound',
#    'datamodel': 'classification',
#    'source': [{'label': 'ChEMBL-RDF',
#      'url': 'http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBL-RDF/',
#      'version': 'CHEMBL31',
#      'updated': '2022-08-15'}]},
#   'compound_drug_development_phase_chembl': {'label': 'Drug development phase',
#    'description': "Classification based on the drug's development phase (research stage, phase I-III, and post-launch) from ChEMBL",
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_drug_development_phase_chembl',
#    'order': 'numerical_desc',
#    'dataset': 'chembl_compound',
#    'datamodel': 'classification',
#    'source': [{'label': 'ChEMBL-RDF',
#      'url': 'http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBL-RDF/',
#      'version': 'CHEMBL31',
#      'updated': '2022-08-15'}]},
#   'compound_atc_classification_pubchem': {'label': 'PubChem ATC classification',
#    'description': 'Classification of a medicine (in PubChem) according to its medicinal properties (WHO ATC Code)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_atc_classification_pubchem',
#    'order': 'numerical_desc',
#    'dataset': 'pubchem_compound',
#    'datamodel': 'classification',
#    'source': [{'label': 'PubChem',
#      'url': 'http://ftp.ncbi.nlm.nih.gov/pubchem/RDF/',
#      'version': 'Ver:2022-12-15',
#      'updated': '2022-12-15'}]},
#   'compound_atc_classification_chembl': {'label': 'ChEMBL ATC classification',
#    'description': 'Classification of a medicine (in ChEMBL) according to its medicinal properties (WHO ATC Code)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/compound_atc_classification_chembl',
#    'order': 'numerical_desc',
#    'dataset': 'chembl_compound',
#    'datamodel': 'classification',
#    'source': [{'label': 'ChEMBL-RDF',
#      'url': 'http://ftp.ebi.ac.uk/pub/databases/chembl/ChEMBL-RDF/',
#      'version': 'CHEMBL31',
#      'updated': '2022-08-15'}]},
#   'glycan_mass_glycosmos': {'label': 'Molecular mass of glycans',
#    'description': 'Molecular weight of glycans from GlyCosmos',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/glycan_mass_glycosmos',
#    'dataset': 'glytoucan',
#    'datamodel': 'distribution',
#    'source': [{'label': 'GlyCosmos',
#      'url': 'https://glycosmos.org/release',
#      'version': 'v1.7.0',
#      'updated': '2021-08-09'}]},
#   'glycan_tissue_glycosmos': {'label': 'Tissues',
#    'description': 'Tissues where glycans are expressed',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/glycan_tissue_glycosmos',
#    'order': 'numerical_desc',
#    'dataset': 'glytoucan',
#    'datamodel': 'classification',
#    'source': [{'label': 'GlyCosmos',
#      'url': 'https://glycosmos.org/release',
#      'version': 'v1.7.0',
#      'updated': '2021-08-09'}]},
#   'glycan_subsumption_glycosmos': {'label': 'Subsumption',
#    'description': 'The relationship between four levels of glycan types registered in GlyCosmos. For details, see <a href="https://glycosmos.org/faq" target="_blank">the Help page of GlyCosmos</a>.',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/glycan_subsumption_glycosmos',
#    'order': 'id_asc',
#    'dataset': 'glytoucan',
#    'datamodel': 'classification',
#    'source': [{'label': 'GlyCosmos',
#      'url': 'https://glycosmos.org/release',
#      'version': 'v1.7.0',
#      'updated': '2021-08-09'}]},
#   'disease_diseases_mondo': {'label': 'Diseases in Mondo',
#    'description': 'Subcategories in the Disease or disorder category in the Mondo Disease Ontology (Mondo)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/disease_diseases_mondo',
#    'order': 'numerical_desc',
#    'dataset': 'mondo',
#    'datamodel': 'classification',
#    'source': [{'label': 'Mondo Disease Ontology (Mondo)',
#      'url': 'https://mondo.monarchinitiative.org/',
#      'version': 'v2022-12-01',
#      'updated': '2022-12-01'}]},
#   'disease_diseases_mesh': {'label': 'Diseases in MeSH',
#    'description': 'Subcategories in the Disease category in Medical Subject Headings (MeSH)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/disease_diseases_mesh',
#    'order': 'numerical_desc',
#    'dataset': 'mesh',
#    'datamodel': 'classification',
#    'source': [{'label': 'Medical Subject Headings (MeSH)',
#      'url': 'https://www.nlm.nih.gov/mesh/meshhome.html',
#      'version': 'N/A',
#      'updated': '2022-12-16'}]},
#   'disease_diseases_nando': {'label': 'Diseases in NANDO',
#    'description': 'Japanese rare and intractable disease categories in the Nanbyo Disease Ontology (NANDO)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/disease_diseases_nando',
#    'order': 'numerical_desc',
#    'dataset': 'nando',
#    'datamodel': 'classification',
#    'source': [{'label': 'Nanbyo Disease Ontology (NANDO)',
#      'url': 'http://nanbyodata.jp/ontology/nando',
#      'version': '1.01',
#      'updated': '2021-08-05'}]},
#   'disease_related_dbs_mondo': {'label': 'Cross referenced disease DBs in Mondo',
#    'description': 'Number of entries linked to Mondo in each of approx. 70 disease related databases from database cross reference in Mondo',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/disease_related_dbs_mondo',
#    'order': 'numerical_desc',
#    'dataset': 'mondo',
#    'datamodel': 'classification',
#    'source': [{'label': 'Mondo Disease Ontology (Mondo)',
#      'url': 'https://mondo.monarchinitiative.org/',
#      'version': 'v2022-12-01',
#      'updated': '2022-12-01'}]},
#   'disease_phenotypic_abnormality_hpo': {'label': 'Phenotypic abnormality',
#    'description': 'Classification the subcategories of the Phenotypic abnormality categories of the Human Phenotype Ontology (HPO)',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/disease_phenotypic_abnormality_hpo',
#    'order': 'numerical_desc',
#    'dataset': 'hp',
#    'datamodel': 'classification',
#    'source': [{'label': 'Human Phenotype Ontology (HPO)',
#      'url': 'https://hpo.jax.org/app/browse/term/HP:0000118',
#      'version': 'N/A',
#      'updated': '2022-12-15'}]},
#   'variant_gwas_togovar': {'label': 'GWAS',
#    'description': 'Classification of statistically significant variants in genome-wide association studies (GWAS) based on associated traits. Obtained from GWAS catalog via TogoVar',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/variant_gwas_togovar',
#    'order': 'numerical_desc',
#    'dataset': 'togovar',
#    'datamodel': 'classification',
#    'source': [{'label': 'GWAS Catalog All associations ',
#      'url': 'https://www.ebi.ac.uk/gwas/docs/file-downloads',
#      'version': 'N/A',
#      'updated': '2022-12-16'}]},
#   'variant_clinical_significance_togovar': {'label': 'Clinical significance',
#    'description': 'Classification of variants according to their clinical significance, such as whether they are the cause of the disease or not. Obtained from ClinVar via TogoVar',
#    'api': 'https://togodx.dbcls.jp/human/breakdown/variant_clinical_significance_togovar',
#    'order': 'numerical_desc',
#    'dataset': 'togovar',
#    'datamodel': 'classification',
#    'source': [{'label': 'ClinVar',
#      'url': 'https://www.ncbi.nlm.nih.gov/clinvar/docs/clinsig/',
#      'version': 'N/A',
#      'updated': '2022-12-01'}]}},
#  'datasets': {'ensembl_gene': {'label': 'Ensembl gene',
#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates

#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/glytoucan.hbs',
#    'target': True,
#    'examples': ['G00049MO',
#     'G00056MO',
#     'G99053DY',
#     'G01534TU',
#     'G19749DC',
#     'G11647UD',
#     'G17126MK',
#     'G17173XA',
#     'G64904FE',
#     'G58670TY'],
#    'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,pubchem_compound,chebi&ids=',
#     'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,pubchem_compound,chembl_compound&ids=',
#     'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,chembl_target&ids=',
#     'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,ensembl_gene&ids=',
#     'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,hgnc&ids=',
#     'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,medgen,hp&ids=',
#     'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,medgen&ids=',
#     'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,mesh&ids=',
#     'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo&ids=',
#     'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,nando&ids=',
#     'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,ncbigene&ids=',
#     'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,omim_phenotype&ids=',
#     'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,orphanet&ids=',
#     'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,pdb&ids=',
#     'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,pubchem_compound&ids=',
#     'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,hgnc,togovar&ids=',
#     'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot&ids='}},
#   'mondo': {'label': 'Mondo',
#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/mondo.hbs',
#    'target': True,
#    'examples': ['0010679', '0011925', '0000355', '0009678', '0016830'],
#    'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,chebi&ids=',
#     'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,chembl_compound&ids=',
#     'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,chembl_target&ids=',
#     'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,ensembl_gene&ids=',
#     'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,doid,glytoucan&ids=',
#     'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,hgnc&ids=',
#     'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,hp&ids=',
#     'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen&ids=',
#     'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,mesh&ids=',
#     'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,nando&ids=',
#     'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene&ids=',
#     'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,omim_phenotype&ids=',
#     'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,orphanet&ids=',
#     'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,uniprot,pdb&ids=',
#     'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,pubchem_compound&ids=',
#     'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,togovar&ids=',
#     'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,uniprot&ids='}},
#   'mesh': {'label': 'MeSH',
#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/mesh.hbs',
#    'target': True,
#    'examples': ['D013584', 'D018234', 'D018232', 'D002813'],
#    'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,chebi&ids=',
#     'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,chembl_compound&ids=',
#     'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,chembl_target&ids=',
#     'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,ensembl_gene&ids=',
#     'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,doid,glytoucan&ids=',
#     'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,hgnc&ids=',
#     'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,mondo,hp&ids=',
#     'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,medgen&ids=',
#     'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo&ids=',
#     'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,nando&ids=',
#     'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene&ids=',
#     'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,omim_phenotype&ids=',
#     'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,orphanet&ids=',
#     'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,uniprot,pdb&ids=',
#     'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,pubchem_compound&ids=',
#     'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,togovar&ids=',
#     'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,uniprot&ids='}},
#   'nando': {'label': 'NANDO',
#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/nando.hbs',
#    'target': True,
#    'examples': ['2200856', '2200857', '2200860', '2200861', '2200862'],
#    'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,medgen,mondo,mesh,chembl_compound,chebi&ids=',
#     'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,medgen,mondo,mesh,chembl_compound&ids=',
#     'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,chembl_target&ids=',
#     'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,ensembl_gene&ids=',
#     'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,doid,glytoucan&ids=',
#     'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,hgnc&ids=',
#     'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,hp&ids=',
#     'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen&ids=',
#     'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,mesh&ids=',
#     'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo&ids=',
#     'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene&ids=',
#     'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,omim_phenotype&ids=',
#     'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,orphanet&ids=',
#     'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,uniprot,pdb&ids=',
#     'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,medgen,mondo,mesh,chembl_compound,pubchem_compound&ids=',
#     'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,togovar&ids=',
#     'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,uniprot&ids='}},
#   'hp': {'label': 'Human Phenotype Ontology',
#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/hp.hbs',
#    'target': True,
#    'examples': ['0012570', '0012218', '0006779', '0006765'],
#    'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh,chembl_compound,chebi&ids=',
#     'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh,chembl_compound&ids=',
#     'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,chembl_target&ids=',
#     'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,ensembl_gene&ids=',
#     'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,doid,glytoucan&ids=',
#     'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,hgnc&ids=',
#     'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo&ids=',
#     'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh&ids=',
#     'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo&ids=',
#     'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,nando&ids=',
#     'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene&ids=',
#     'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,omim_phenotype&ids=',
#     'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,orphanet&ids=',
#     'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,uniprot,pdb&ids=',
#     'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh,chembl_compound,pubchem_compound&ids=',
#     'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,togovar&ids=',
#     'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,uniprot&ids='}},
#   'togovar': {'label': 'TogoVar variant',
#    'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/togovar.hbs',
#    'target': False,
#    'examples': ['tgv100005930',
#     'tgv100000890',
#     'tgv16331',
#     'tgv10000341',
#     'tgv21330879'],
#    'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,reactome_reaction,chebi&ids=',
#     'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,reactome_reaction,chebi,chembl_compound&ids=',
#     'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,chembl_target&ids=',
#     'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,ensembl_gene&ids=',
#     'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,glytoucan&ids=',
#     'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc&ids=',
#     'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,hp&ids=',
#     'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen&ids=',
#     'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,mesh&ids=',
#     'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,mondo&ids=',
#     'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,mondo,nando&ids=',
#     'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,ncbigene&ids=',
#     'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,omim_phenotype&ids=',
#     'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,orphanet&ids=',
#     'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,pdb&ids=',
#     'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,reactome_reaction,chebi,pubchem_compound&ids=',
#     'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot&ids='}}}}

# %%
togoid_dataset_config_url = 'https://github.com/togoid/togoid-config/raw/main/config/dataset.yaml'
dataset_config = yaml.safe_load(urlopen(togoid_dataset_config_url).read())
dataset_config
# Out:
# {'affy_probeset': {'label': 'Affymetrix probeset',
#   'catalog': 'FIXME',
#   'category': 'Probe',
#   'regex': '^(?<id>\\d{3,}(?:_[a-z])?_at)$',
#   'prefix': 'http://identifiers.org/affy.probeset/',
#   'examples': [['1553582_a_at',
#     '211531_x_at',
#     '202573_at',
#     '201640_x_at',
#     '205117_at',
#     '201017_at',
#     '205099_s_at',
#     '200614_at',
#     '201895_at',
#     '202666_s_at']]},
#  'assembly_insdc': {'label': 'Assembly INSDC',
#   'catalog': 'FIXME',
#   'category': 'Genome',
#   'regex': '^(?<id>GCA_\\d{9})(\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/assembly/',
#   'examples': [['GCA_000001215',
#     'GCA_000001405',
#     'GCA_000001545',
#     'GCA_000001635',
#     'GCA_000001735',
#     'GCA_000001765',
#     'GCA_000001895',
#     'GCA_000001905',
#     'GCA_000001985',
#     'GCA_000002035'],
#    ['GCA_000001215.4',
#     'GCA_000001405.29',
#     'GCA_000001545.3',
#     'GCA_000001635.9',
#     'GCA_000001735.2',
#     'GCA_000001765.3',
#     'GCA_000001895.4',
#     'GCA_000001905.1',
#     'GCA_000001985.1',
#     'GCA_000002035.4']]},
#  'assembly_refseq': {'label': 'Assembly RefSeq',
#   'catalog': 'FIXME',
#   'category': 'Genome',
#   'regex': '^(?<id>GCF_\\d{9})(\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/assembly/',
#   'examples': [['GCF_000002035',
#     'GCF_009870125',
#     'GCF_000840205',
#     'GCF_000004195',
#     'GCF_000475195',
#     'GCF_000296755',
#     'GCF_000151885',
#     'GCF_000715135',
#     'GCF_001039355',
#     'GCF_000331145'],
#    ['GCF_000002035.6',
#     'GCF_009870125.1',
#     'GCF_000840205.1',
#     'GCF_000004195.4',
#     'GCF_000475195.1',
#     'GCF_000296755.1',
#     'GCF_000151885.1',
#     'GCF_000715135.1',
#     'GCF_001039355.2',
#     'GCF_000331145.1']]},
#  'atc': {'label': 'ATC classification',
#   'catalog': 'FIXME',
#   'category': 'Drug',
#   'regex': '^(?<id>[A-Z]\\d{2}[A-Z]{2}\\d{2})$',
#   'prefix': 'http://identifiers.org/atc/',
#   'example': [['J01DD11',
#     'B02BA02',
#     'A03AD30',
#     'R03AC17',
#     'J01CA05',
#     'D07AB07',
#     'D07XB03',
#     'G04CA01',
#     'S01BC11',
#     'G03DB05']]},
#  'bioproject': {'label': 'BioProject',
#   'catalog': 'nbdc00476',
#   'category': 'Project',
#   'regex': '^(?<id>PRJ[DEN][A-Z]\\d+)$',
#   'prefix': 'http://identifiers.org/bioproject/',
#   'examples': [['PRJDB575',
#     'PRJDB1880',
#     'PRJDB478',
#     'PRJDA45949',
#     'PRJEB6285',
#     'PRJEA28961',
#     'PRJEB2222',
#     'PRJNA30641',
#     'PRJNA68235',
#     'PRJNA42549']]},
#  'biosample': {'label': 'BioSample',
#   'catalog': 'nbdc01983',
#   'category': 'Sample',
#   'regex': '^(?<id>SAM[NED]\\w?\\d+)$',
#   'prefix': 'http://identifiers.org/biosample/',
#   'examples': [['SAMD00003683',
#     'SAMD00006315',
#     'SAMD00003741',
#     'SAMD00011226',
#     'SAMN13091859',
#     'SAMN05877962',
#     'SAMN05877838',
#     'SAMEA104232303',
#     'SAMEA4760552',
#     'SAMEA1572228']]},
#  'ccds': {'label': 'Consensus CDS',
#   'catalog': 'nbdc00023',
#   'category': 'Gene',
#   'regex': '^(?<id>CCDS\\d+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/ccds/',
#   'examples': [['CCDS1471',
#     'CCDS10913',
#     'CCDS14790',
#     'CCDS35175',
#     'CCDS2395',
#     'CCDS58412',
#     'CCDS55555',
#     'CCDS34401',
#     'CCDS41889',
#     'CCDS9052'],
#    ['CCDS1471.1',
#     'CCDS10913.1',
#     'CCDS14790.1',
#     'CCDS35175.2',
#     'CCDS2395.1',
#     'CCDS58412.1',
#     'CCDS55555.1',
#     'CCDS34401.2',
#     'CCDS41889.1',
#     'CCDS9052.1']]},
#  'cellosaurus': {'label': 'Cellosaurus',
#   'catalog': 'nbdc02180',
#   'category': 'CellLine',
#   'regex': '^CVCL[:_](?<id>[A-Z0-9]{4})$',
#   'prefix': 'http://www.cellosaurus.org/CVCL_',
#   'format': ['CVCL:%s', 'CVCL_%s'],
#   'examples': [['CVCL:7T24',
#     'CVCL:SE45',
#     'CVCL:XG73',
#     'CVCL:B6HT',
#     'CVCL:WM34',
#     'CVCL:7891',
#     'CVCL:FV52',
#     'CVCL:0367',
#     'CVCL:9Z18',
#     'CVCL:CG19'],
#    ['CVCL_7T24',
#     'CVCL_SE45',
#     'CVCL_XG73',
#     'CVCL_B6HT',
#     'CVCL_WM34',
#     'CVCL_7891',
#     'CVCL_FV52',
#     'CVCL_0367',
#     'CVCL_9Z18',
#     'CVCL_CG19']]},
#  'chebi': {'label': 'ChEBI compound',
#   'catalog': 'nbdc00027',
#   'category': 'Compound',
#   'regex': '^(?:CHEBI[:_])?(?<id>\\d+)$',
#   'prefix': 'http://purl.obolibrary.org/obo/CHEBI_',
#   'format': ['%s', 'CHEBI:%s', 'CHEBI_%'],
#   'examples': [['84824',
#     '40167',
#     '32807',
#     '87666',
#     '57524',
#     '64860',
#     '94440',
#     '18005',
#     '4806',
#     '50158'],
#    ['CHEBI:84824',
#     'CHEBI:40167',
#     'CHEBI:32807',
#     'CHEBI:87666',
#     'CHEBI:57524',
#     'CHEBI:64860',
#     'CHEBI:94440',
#     'CHEBI:18005',
#     'CHEBI:4806',
#     'CHEBI:50158'],
#    ['CHEBI_84824',
#     'CHEBI_40167',
#     'CHEBI_32807',
#     'CHEBI_87666',
#     'CHEBI_57524',
#     'CHEBI_64860',
#     'CHEBI_94440',
#     'CHEBI_18005',
#     'CHEBI_4806',
#     'CHEBI_50158']]},
#  'chembl_compound': {'label': 'ChEMBL compound',
#   'catalog': 'nbdc02555',
#   'category': 'Compound',
#   'regex': '^(?<id>CHEMBL\\d+)$',
#   'prefix': 'http://identifiers.org/chembl.compound/',
#   'examples': [['CHEMBL121649',
#     'CHEMBL190334',
#     'CHEMBL3103282',
#     'CHEMBL69329',
#     'CHEMBL2105131',
#     'CHEMBL2177390',
#     'CHEMBL3091820',
#     'CHEMBL1200335',
#     'CHEMBL3094412',
#     'CHEMBL67367']]},
#  'chembl_target': {'label': 'ChEMBL target',
#   'catalog': 'nbdc02555',
#   'category': 'Protein',
#   'regex': '^(?<id>CHEMBL\\d+)$',
#   'prefix': 'http://identifiers.org/chembl.target/',
#   'examples': [['CHEMBL2788',
#     'CHEMBL3091264',
#     'CHEMBL3831324',
#     'CHEMBL5524',
#     'CHEMBL5597',
#     'CHEMBL3983',
#     'CHEMBL4187',
#     'CHEMBL3391681',
#     'CHEMBL5135',
#     'CHEMBL1255130']]},
#  'civic_gene': {'label': 'CIVIC gene',
#   'catalog': 'nbdc02558',
#   'category': 'Gene',
#   'regex': '^(?<id>\\d+)$',
#   'prefix': 'http://civic.genome.wustl.edu/links/genes/'},
#  'clinvar': {'label': 'ClinVar variant',
#   'catalog': 'nbdc01514',
#   'category': 'Variant',
#   'regex': '^(VCV0*)?(?<id>(\\d{1,9}))$',
#   'prefix': 'http://identifiers.org/clinvar/',
#   'format': ['%s', 'VCV%09d'],
#   'examples': [['658761',
#     '619209',
#     '745342',
#     '11955',
#     '731668',
#     '724289',
#     '725734',
#     '743127',
#     '789913',
#     '5302'],
#    ['VCV000658761',
#     'VCV000619209',
#     'VCV000745342',
#     'VCV000011955',
#     'VCV000731668',
#     'VCV000724289',
#     'VCV000725734',
#     'VCV000743127',
#     'VCV000789913',
#     'VCV000005302']]},
#  'dbsnp': {'label': 'dbSNP',
#   'catalog': 'nbdc00206',
#   'category': 'Variant',
#   'regex': '^(?<id>rs\\d+)$',
#   'prefix': 'http://identifiers.org/dbsnp/',
#   'examples': [['rs746303788',
#     'rs1407020249',
#     'rs374003162',
#     'rs4647297',
#     'rs549539526',
#     'rs1387864740',
#     'rs1177577242',
#     'rs769848663',
#     'rs16961655',
#     'rs79135400']]},
#  'dgidb': {'label': 'DGIdb',
#   'catalog': 'nbdc02562',
#   'category': 'Interaction',
#   'regex': '^[a-z0-9]{8}-[a-z0-9]{4}-[a-z0-9]{4}-[a-z0-9]{4}-[a-z0-9]{12}',
#   'prefix': 'FIXME'},
#  'doid': {'label': 'Disease ontology',
#   'catalog': 'nbdc00261',
#   'category': 'Disease',
#   'regex': '^DO(?:ID)?[:_](?<id>\\d+)$',
#   'prefix': 'http://purl.obolibrary.org/obo/DOID_',
#   'format': ['DO:%s', 'DOID:%s', 'DOID_%s'],
#   'examples': [['DO:9036',
#     'DO:3159',
#     'DO:10964',
#     'DO:12698',
#     'DO:0060459',
#     'DO:11840',
#     'DO:11339',
#     'DO:914',
#     'DO:9945',
#     'DO:1407'],
#    ['DOID:9036',
#     'DOID:3159',
#     'DOID:10964',
#     'DOID:12698',
#     'DOID:0060459',
#     'DOID:11840',
#     'DOID:11339',
#     'DOID:914',
#     'DOID:9945',
#     'DOID:1407'],
#    ['DOID_9036',
#     'DOID_3159',
#     'DOID_10964',
#     'DOID_12698',
#     'DOID_0060459',
#     'DOID_11840',
#     'DOID_11339',
#     'DOID_914',
#     'DOID_9945',
#     'DOID_1407']]},
#  'drugbank': {'label': 'DrugBank',
#   'catalog': 'nbdc01071',
#   'category': 'Compound',
#   'regex': '^(?<id>DB\\d{5})$',
#   'prefix': 'http://identifiers.org/drugbank/',
#   'examples': [['DB15589',
#     'DB13471',
#     'DB05830',
#     'DB07423',
#     'DB07074',
#     'DB08912',
#     'DB02908',
#     'DB05088',
#     'DB05229',
#     'DB08910']]},
#  'ec': {'label': 'Enzyme nomenclature',
#   'catalog': 'nbdc01883',
#   'category': 'Function',
#   'regex': '^(?:EC:)?(?<id>\\d+\\.(?:(?:-\\.-\\.-)|\\d+\\.(?:(?:-\\.-)|\\d+\\.(?:-|n?\\d+))))$',
#   'prefix': 'http://identifiers.org/ec-code/',
#   'format': ['%s', 'EC:%s'],
#   'examples': [['1.6.3.1',
#     '2.4.1.353',
#     '1.1.1.288',
#     '1.5.1.2',
#     '3.1.1.71',
#     '1.3.1.31',
#     '3.5.1.29',
#     '1.16.1.1',
#     '3.1.3.48',
#     '2.3.1.138'],
#    ['EC:1.6.3.1',
#     'EC:2.4.1.353',
#     'EC:1.1.1.288',
#     'EC:1.5.1.2',
#     'EC:3.1.1.71',
#     'EC:1.3.1.31',
#     'EC:3.5.1.29',
#     'EC:1.16.1.1',
#     'EC:3.1.3.48',
#     'EC:2.3.1.138']]},
#  'ena': {'catalog': 'nbdc00432',
#   'category': 'Gene',
#   'label': 'ENA',
#   'regex': '^(?:ena\\.embl:)?(?<id>[A-Z]+[0-9]+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/ena.embl/'},
#  'ensembl_gene': {'label': 'Ensembl gene',
#   'catalog': 'nbdc00054',
#   'category': 'Gene',
#   'regex': '^(?:(?:(?<id1>ENS[A-Z]*G\\d{11})(?:\\.\\d+)?)|(?<id2>FBgn\\d{7})|(?:(?<id3>MGP_[A-Za-z0-9]+_G\\d{7})(?:\\.\\d+)?)|(?<id4>LRG_\\d+)|(?<id5>WBGene\\d{8})|(?<id6>Y[A-Z]{2}\\d{3}[A-Z](?:-[A-Z])?)|(?<id7>Q\\d{4})|(?<id8>[A-Z]{3}\\d{1,3}(?:-\\d)?)|(?<id9>snR\\d+-?[A-Za-z]?)|(?<id10>t[A-Z]\\([ACGUX]{3}\\)[A-Z]\\d?))$',
#   'prefix': 'http://identifiers.org/ensembl/',
#   'examples': [['ENSG00000186283',
#     'ENSAMEG00000018238',
#     'ENSG00000167916',
#     'ENSG00000213417',
#     'ENSG00000133328',
#     'ENSG00000274404',
#     'ENSG00000184363',
#     'FBgn0021742',
#     'FBgn0030057',
#     'FBgn0265139']]},
#  'ensembl_protein': {'label': 'Ensembl protein',
#   'catalog': 'nbdc00054',
#   'category': 'Protein',
#   'regex': '^(?:(?:(?<id1>ENS[A-Z]*P\\d{11})(?:\\.\\d+)?)|(?<id2>FBpp\\d{7})|(?:(?<id3>MGP_[A-Za-z0-9]+_P\\d{7})(?:\\.\\d+)?)|(?<id4>LRG_\\d+p\\d+(?:-\\d)?)|(?<id5>(?:[A-Za-z0-9][A-Za-z0-9_]+)\\.t?\\d+[a-z]?(?:\\.\\d+)?)|(?<id6>Y[A-Z]{2}\\d{3}[A-Z](?:-[A-Z])?)|(?<id7>Q\\d{4}))$',
#   'prefix': 'http://identifiers.org/ensembl/',
#   'examples': [['ENSP00000365411',
#     'ENSP00000420674',
#     'ENSAZOP00000020796',
#     'FBpp0070277',
#     'FBpp0070535',
#     'ENSAZOP00000019433',
#     'ENSP00000372042',
#     'ENSAZOP00000017910',
#     'ENSP00000370977',
#     'ENSP00000481894']]},
#  'ensembl_transcript': {'label': 'Ensembl transcript',
#   'catalog': 'nbdc00054',
#   'category': 'Transcript',
#   'regex': '^(?:(?:(?<id1>ENS[A-Z]*T\\d{11})(?:\\.\\d+)?)|(?<id2>FBtr\\d{7})|(?:(?<id3>MGP_[A-Za-z0-9]+_T\\d{7})(?:\\.\\d+)?)|(?<id4>LRG_\\d+t\\d+(?:-\\d)?)|(?<id5>(?:[A-Za-z0-9][A-Za-z0-9_]+)\\.t?\\d+[a-z]?(?:\\.\\d+)?)|(?<id6>Y[A-Z]{2}\\d{3}[A-Z](?:-[A-Z])?(?:_[a-z]{1,3}RNA)?)|(?<id7>Q\\d{4}_[a-z]{1,3}RNA)|(?<id8>[A-Z]{3}\\d{1,3}(?:-\\d)?_[a-z]{1,3}RNA)|(?<id9>snR\\d+-?[A-Za-z]?_sno?RNA)|(?<id10>t[A-Z]\\([ACGUX]{3}\\)[A-Z]\\d?_tRNA))$',
#   'prefix': 'http://identifiers.org/ensembl/',
#   'examples': [['ENST00000638000',
#     'ENST00000307864',
#     'ENSTRUT00000006732',
#     'ENSAMET00000021072',
#     'ENSAZOT00000021040',
#     'ENST00000622541',
#     'ENST00000462612',
#     'ENSBTAT00000072441',
#     'ENSAZOT00000005048',
#     'ENST00000475822']]},
#  'flybase_gene': {'label': 'FlyBase Gene',
#   'catalog': 'nbdc00064',
#   'category': 'Gene',
#   'regex': '^(?<id>FBgn\\d{7})$',
#   'prefix': 'http://identifiers.org/fb/',
#   'examples': [['FBgn0040373',
#     'FBgn0040372',
#     'FBgn0261446',
#     'FBgn0000316',
#     'FBgn0005427',
#     'FBgn0040370',
#     'FBgn0040371',
#     'FBgn0029521',
#     'FBgn0024989',
#     'FBgn0004034']]},
#  'gea': {'label': 'GEA',
#   'catalog': 'FIXME',
#   'category': 'Experiment',
#   'regex': '^(?<id>E-GEAD-\\d+)$',
#   'prefix': 'https://ddbj.nig.ac.jp/public/ddbj_database/gea/experiment/E-GEAD-000/',
#   'examples': [['E-GEAD-446',
#     'E-GEAD-519',
#     'E-GEAD-328',
#     'E-GEAD-349',
#     'E-GEAD-284',
#     'E-GEAD-448',
#     'E-GEAD-460',
#     'E-GEAD-348',
#     'E-GEAD-344',
#     'E-GEAD-385']]},
#  'glytoucan': {'label': 'GlyTouCan',
#   'catalog': 'nbdc01535',
#   'category': 'Glycan',
#   'regex': '^(?<id>G[0-9]{5}[A-Z]{2})$',
#   'prefix': 'http://identifiers.org/glytoucan/',
#   'examples': [['G88006IV',
#     'G53085MI',
#     'G17896UT',
#     'G50341PG',
#     'G19379ID',
#     'G08110WX',
#     'G70101JE',
#     'G45504EY',
#     'G81263BG',
#     'G02815KT']]},
#  'go': {'label': 'Gene ontology',
#   'catalog': 'nbdc00074',
#   'category': 'Function',
#   'regex': '^GO[:_](?<id>\\d{7})$',
#   'prefix': 'http://purl.obolibrary.org/obo/GO_',
#   'format': ['GO:%s', 'GO_%s'],
#   'examples': [['GO:0005643',
#     'GO:0097110',
#     'GO:0097225',
#     'GO:0052855',
#     'GO:2000012',
#     'GO:0042921',
#     'GO:0019774',
#     'GO:0085018',
#     'GO:0009508',
#     'GO:0046470'],
#    ['GO_0005643',
#     'GO_0097110',
#     'GO_0097225',
#     'GO_0052855',
#     'GO_2000012',
#     'GO_0042921',
#     'GO_0019774',
#     'GO_0085018',
#     'GO_0009508',
#     'GO_0046470']]},
#  'hgnc': {'label': 'HGNC',
#   'catalog': 'nbdc01774',
#   'category': 'Gene',
#   'regex': '^(?:(?:HGNC|hgnc):)?(?<id>\\d{1,5})$',
#   'prefix': 'http://identifiers.org/hgnc/',
#   'format': ['%s', 'HGNC:%s', 'hgnc:%s'],
#   'examples': [['26199',
#     '38937',
#     '14027',
#     '21498',
#     '18185',
#     '1314',
#     '25960',
#     '2206',
#     '22224',
#     '19741'],
#    ['HGNC:26199',
#     'HGNC:38937',
#     'HGNC:14027',
#     'HGNC:21498',
#     'HGNC:18185',
#     'HGNC:1314',
#     'HGNC:25960',
#     'HGNC:2206',
#     'HGNC:22224',
#     'HGNC:19741'],
#    ['hgnc:26199',
#     'hgnc:38937',
#     'hgnc:14027',
#     'hgnc:21498',
#     'hgnc:18185',
#     'hgnc:1314',
#     'hgnc:25960',
#     'hgnc:2206',
#     'hgnc:22224',
#     'hgnc:19741']]},
#  'hgnc_symbol': {'label': 'HGNC gene symbol',
#   'catalog': 'nbdc01774',
#   'category': 'Gene',
#   'regex': '^(?<id>[A-Za-z0-9_\\-]+\\@?)$',
#   'prefix': 'http://identifiers.org/hgnc.symbol/',
#   'examples': [['MBNL2',
#     'RGS20',
#     'LINC02011',
#     'IGHV1-14',
#     'SH3RF2',
#     'SPATA13',
#     'HNRNPCP10',
#     'LINC00334',
#     'TMEM241',
#     'RN7SL753P']]},
#  'hmdb': {'label': 'HMDB',
#   'catalog': 'nbdc00909',
#   'category': 'Compound',
#   'regex': '^(?:hmdb:)?(?<id>HMDB\\d+)$',
#   'prefix': 'http://identifiers.org/hmdb/',
#   'format': ['%s', 'hmdb:%s'],
#   'examples': [['HMDB0029433',
#     'HMDB0015609',
#     'HMDB0000042',
#     'HMDB0002360',
#     'HMDB0003345',
#     'HMDB0003550',
#     'HMDB0036769',
#     'HMDB0000935',
#     'HMDB0002755',
#     'HMDB0004369'],
#    ['hmdb:HMDB0029433',
#     'hmdb:HMDB0015609',
#     'hmdb:HMDB0000042',
#     'hmdb:HMDB0002360',
#     'hmdb:HMDB0003345',
#     'hmdb:HMDB0003550',
#     'hmdb:HMDB0036769',
#     'hmdb:HMDB0000935',
#     'hmdb:HMDB0002755',
#     'hmdb:HMDB0004369']]},
#  'homologene': {'label': 'HomoloGene',
#   'catalog': 'nbdc00101',
#   'category': 'Ortholog',
#   'regex': '^(?<id>\\d+)$',
#   'prefix': 'http://identifiers.org/homologene/',
#   'examples': [['117',
#     '17',
#     '6',
#     '142',
#     '55',
#     '132',
#     '61',
#     '109',
#     '137',
#     '134']]},
#  'cog': {'label': 'COG',
#   'catalog': 'nbdc00397',
#   'category': 'Ortholog',
#   'regex': '^(?<id>COG\\d{4})$',
#   'prefix': 'https://www.ncbi.nlm.nih.gov/research/cog/cog/',
#   'examples': [['COG0130',
#     'COG0663',
#     'COG0762',
#     'COG1186',
#     'COG1285',
#     'COG1390',
#     'COG3079',
#     'COG3354',
#     'COG4957',
#     'COG5379']]},
#  'hp': {'label': 'Human Phenotype Ontology',
#   'catalog': 'nbdc02559',
#   'category': 'Disease',
#   'regex': '^HP[:_](?<id>\\d{7})$',
#   'prefix': 'http://purl.obolibrary.org/obo/HP_',
#   'format': ['HP:%s', 'HP_%s'],
#   'examples': [['HP:0001947',
#     'HP:0031592',
#     'HP:0012085',
#     'HP:0000956',
#     'HP:0025238',
#     'HP:0002861',
#     'HP:0001680',
#     'HP:0004417',
#     'HP:0001701',
#     'HP:0025084'],
#    ['HP_0001947',
#     'HP_0031592',
#     'HP_0012085',
#     'HP_0000956',
#     'HP_0025238',
#     'HP_0002861',
#     'HP_0001680',
#     'HP_0004417',
#     'HP_0001701',
#     'HP_0025084']]},
#  'human_protein_atlas': {'label': 'Human Protein Atlas',
#   'catalog': 'nbdc00905',
#   'category': 'Protein',
#   'regex': '^(?<id>ENSG\\d{11})$',
#   'prefix': 'http://www.proteinatlas.org/'},
#  'inchi_key': {'label': 'InChIKey',
#   'catalog': 'FIXME',
#   'category': 'Compound',
#   'regex': '^(?<id>[A-Z]{14}\\-[A-Z]{10}(\\-[A-Z])?)$',
#   'prefix': 'http://identifiers.org/inchikey/',
#   'examples': [['RYYVLZVUVIJVGH-UHFFFAOYSA-N',
#     'RZWGTXHSYZGXKF-UHFFFAOYSA-N',
#     'RQQIIXFYTHWFKW-ZETCQYMHSA-N',
#     'RALAARQREFCZJO-UHFFFAOYSA-N',
#     'HVFRJJDZWVSUIB-UHFFFAOYSA-N',
#     'KVNZVXVZQFTXNA-UHFFFAOYSA-N',
#     'KVQUJTYBWCGJRS-UHFFFAOYSA-N',
#     'AFGLQVAJWVTAJT-UHFFFAOYSA-N',
#     'LHISABQPMWXWCC-UHFFFAOYSA-N',
#     'ZSXCHLJCWRSMMS-UHFFFAOYSA-N']]},
#  'insdc': {'label': 'GenBank/ENA/DDBJ',
#   'catalog': 'nbdc02567',
#   'category': 'Gene',
#   'regex': '^(?:insdc:)?(?<id>[A-Z]\\d{5}|[A-Z]{2}\\d{6}|[A-Z]{4}\\d{8}|[A-J][A-Z]{2}\\d{5}|[A-Z]{4,}\\d{9})(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/insdc/',
#   'examples': [['U10991',
#     'AF116914',
#     'AK056978',
#     'DQ440258',
#     'U91725',
#     'AY301270',
#     'U32907',
#     'AY261360',
#     'AK001332',
#     'U13261']]},
#  'insdc_master': {'label': 'INSDC master',
#   'catalog': 'nbdc02567',
#   'category': 'Project',
#   'regex': '^(?:insdc:)?(?<id>[A-Z]{4,6}\\d{8,10})(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/insdc/',
#   'examples': [['ABGA00000000',
#     'AADE00000000',
#     'AABR00000000',
#     'AAGU00000000',
#     'ABAR00000000',
#     'AADD00000000',
#     'ABBA00000000',
#     'AAHY00000000',
#     'AADG00000000',
#     'AAGJ00000000']]},
#  'intact': {'label': 'IntAct',
#   'catalog': 'nbdc00507',
#   'category': 'Interaction',
#   'regex': '^(?<id>EBI\\-[0-9]+)$',
#   'prefix': 'http://identifiers.org/intact/',
#   'examples': [['EBI-7947422',
#     'EBI-15714708',
#     'EBI-16225271',
#     'EBI-4406290',
#     'EBI-9026465',
#     'EBI-6403471',
#     'EBI-1113651',
#     'EBI-562824',
#     'EBI-9014072',
#     'EBI-1784742']]},
#  'interpro': {'label': 'InterPro',
#   'catalog': 'nbdc00108',
#   'category': 'Domain',
#   'regex': '^(?<id>IPR\\d{6})$',
#   'prefix': 'http://identifiers.org/interpro/',
#   'examples': [['IPR038152',
#     'IPR040448',
#     'IPR036748',
#     'IPR034266',
#     'IPR005479',
#     'IPR036365',
#     'IPR000174',
#     'IPR001334',
#     'IPR000731',
#     'IPR001767']]},
#  'kegg_compound': {'label': 'KEGG Compound',
#   'catalog': 'nbdc00814',
#   'category': 'Compound',
#   'regex': '^(?<id>C\\d+)$',
#   'prefix': 'http://identifiers.org/kegg.compound/'},
#  'kegg_disease': {'catalog': 'nbdc00813',
#   'category': 'Disease',
#   'label': 'KEGG Disease',
#   'regex': '^KEGG:H(?<id>\\d+)$',
#   'prefix': 'http://identifiers.org/kegg.disease/'},
#  'kegg_drug': {'label': 'KEGG Drug',
#   'catalog': 'nbdc00812',
#   'category': 'Drug',
#   'regex': '^(?<id>D\\d+)$',
#   'prefix': 'http://identifiers.org/kegg.drug/'},
#  'kegg_genes': {'label': 'KEGG Genes',
#   'catalog': 'nbdc00532',
#   'category': 'Gene, Protein',
#   'regex': '^\\w+:[\\w\\d\\.-]*$',
#   'prefix': 'http://identifiers.org/kegg.genes/'},
#  'kegg_orthology': {'label': 'KEGG Orthology',
#   'catalog': 'nbdc00817',
#   'category': 'Ortholog',
#   'regex': '^(?<id>K\\d+)$',
#   'prefix': 'http://identifiers.org/kegg.orthology/'},
#  'kegg_pathway': {'label': 'KEGG Pathway',
#   'catalog': 'nbdc00118',
#   'category': 'Pathway',
#   'regex': '^(?<id>\\w{2,4}\\d{5})$',
#   'prefix': 'http://identifiers.org/kegg.pathway/'},
#  'kegg_reaction': {'label': 'KEGG Reaction',
#   'catalog': 'nbdc00818',
#   'category': 'Interaction',
#   'regex': '^(?<id>R\\d+)$',
#   'prefix': 'http://identifiers.org/kegg.reaction/'},
#  'lrg': {'catalog': 'nbdc02566',
#   'category': 'Gene',
#   'label': 'LRG',
#   'regex': '^(?<id>LRG_\\d+)$',
#   'prefix': 'http://identifiers.org/lrg/',
#   'examples': [['LRG_41',
#     'LRG_356',
#     'LRG_147',
#     'LRG_660',
#     'LRG_498',
#     'LRG_364',
#     'LRG_203',
#     'LRG_162',
#     'LRG_1271',
#     'LRG_884']]},
#  'mbgd_gene': {'label': 'MBGD gene',
#   'catalog': 'nbdc00130',
#   'category': 'Gene',
#   'regex': '^(?<id>[a-z0-9]+:[A-Z0-9_\\.-]+)$',
#   'prefix': 'http://mbgd.genome.ad.jp/rdf/resource/gene/',
#   'examples': [['ash:AL1_RS04670',
#     'ash:AL1_RS08245',
#     'ash:AL1_RS02870',
#     'ash:AL1_RS06610',
#     'ash:AL1_RS06290',
#     'ash:AL1_RS07260',
#     'ash:AL1_RS08410',
#     'ash:AL1_RS01705',
#     'ash:AL1_RS02510',
#     'ash:AL1_RS07245']]},
#  'mbgd_organism': {'label': 'MBGD organism',
#   'catalog': 'nbdc00130',
#   'category': 'Organism',
#   'regex': '^(?<id>[a-z0-9]+)$',
#   'prefix': 'http://mbgd.genome.ad.jp/rdf/resource/organism/',
#   'examples': [['lac',
#     'pfl',
#     'cou',
#     'bvn',
#     'btd',
#     'ctjt',
#     'sha',
#     'lmoj',
#     'dpi',
#     'arp']]},
#  'meddra': {'label': 'MedDRA',
#   'catalog': 'nbdc02564',
#   'category': 'Disease',
#   'regex': '^(?:(?:MedDRA|meddra):)?(?<id>\\d+)$',
#   'prefix': 'http://identifiers.org/meddra/',
#   'format': ['%s', 'MedDRA:%s', 'meddra:%s'],
#   'examples': [['10008033',
#     '10027710',
#     '10062506',
#     '10040493',
#     '10013611',
#     '10065857',
#     '10063143',
#     '10022599',
#     '10042342',
#     '10047883'],
#    ['MedDRA:10008033',
#     'MedDRA:10027710',
#     'MedDRA:10062506',
#     'MedDRA:10040493',
#     'MedDRA:10013611',
#     'MedDRA:10065857',
#     'MedDRA:10063143',
#     'MedDRA:10022599',
#     'MedDRA:10042342',
#     'MedDRA:10047883'],
#    ['meddra:10008033',
#     'meddra:10027710',
#     'meddra:10062506',
#     'meddra:10040493',
#     'meddra:10013611',
#     'meddra:10065857',
#     'meddra:10063143',
#     'meddra:10022599',
#     'meddra:10042342',
#     'meddra:10047883']]},
#  'medgen': {'label': 'MedGen',
#   'catalog': 'nbdc02560',
#   'category': 'Disease',
#   'regex': '^(?<id>CN?\\d{4,7})$',
#   'prefix': 'http://identifiers.org/medgen/',
#   'examples': [['C0264897',
#     'C0028860',
#     'C0018818',
#     'C1848392',
#     'C0006389',
#     'C0020517',
#     'C0000364',
#     'CN227118',
#     'CN203043',
#     'CN292950']]},
#  'mesh': {'label': 'MeSH',
#   'catalog': 'nbdc00132',
#   'category': 'Disease',
#   'regex': '^(?<id>[CD]\\d{6,9})$',
#   'prefix': 'http://id.nlm.nih.gov/mesh/',
#   'examples': [['D002065',
#     'C562829',
#     'C566582',
#     'D010623',
#     'D003327',
#     'D001715',
#     'D000453',
#     'D010260',
#     'C537322',
#     'C563418']]},
#  'mgi': {'label': 'MGI',
#   'catalog': 'nbdc00135',
#   'category': 'Gene',
#   'regex': '^(?:MGI|mgi):(?<id>\\d{5,})$',
#   'prefix': 'http://identifiers.org/mgi/MGI:',
#   'format': ['MGI:%s', 'mgi:%s'],
#   'examples': [['MGI:2387184',
#     'MGI:1920977',
#     'MGI:2442415',
#     'MGI:1098644',
#     'MGI:1196250',
#     'MGI:1914934',
#     'MGI:1914238',
#     'MGI:1919300',
#     'MGI:1914807',
#     'MGI:2145261'],
#    ['mgi:2387184',
#     'mgi:1920977',
#     'mgi:2442415',
#     'mgi:1098644',
#     'mgi:1196250',
#     'mgi:1914934',
#     'mgi:1914238',
#     'mgi:1919300',
#     'mgi:1914807',
#     'mgi:2145261']]},
#  'mirbase': {'label': 'miRBase',
#   'catalog': 'nbdc00136',
#   'category': 'Transcript',
#   'regex': '^(?<id>MI\\d{7})$',
#   'prefix': 'http://identifiers.org/mirbase/',
#   'examples': [['MI0003587',
#     'MI0000252',
#     'MI0000811',
#     'MI0014201',
#     'MI0003578',
#     'MI0000293',
#     'MI0006384',
#     'MI0006361',
#     'MI0000480',
#     'MI0006419']]},
#  'mondo': {'label': 'MONDO',
#   'catalog': 'nbdc02563',
#   'category': 'Disease',
#   'regex': '^MONDO[:_](?<id>\\d{7})$',
#   'prefix': 'http://purl.obolibrary.org/obo/MONDO_',
#   'format': ['MONDO:%s', 'MONDO_%s'],
#   'examples': [['MONDO:0000115',
#     'MONDO:0002345',
#     'MONDO:0011571',
#     'MONDO:0020035',
#     'MONDO:0020920',
#     'MONDO:0004627',
#     'MONDO:0005480',
#     'MONDO:0010852',
#     'MONDO:0002053',
#     'MONDO:0015758'],
#    ['MONDO_0000115',
#     'MONDO_0002345',
#     'MONDO_0011571',
#     'MONDO_0020035',
#     'MONDO_0020920',
#     'MONDO_0004627',
#     'MONDO_0005480',
#     'MONDO_0010852',
#     'MONDO_0002053',
#     'MONDO_0015758']]},
#  'nando': {'label': 'NANDO',
#   'catalog': 'nbdc02557',
#   'category': 'Disease',
#   'regex': '^NANDO[:_](?<id>\\d{7})$',
#   'prefix': 'http://nanbyodata.jp/ontology/NANDO_',
#   'format': ['NANDO:%s', 'NANDO_%s'],
#   'examples': [['NANDO:1200461',
#     'NANDO:1200466',
#     'NANDO:1200851',
#     'NANDO:1200061',
#     'NANDO:1200315',
#     'NANDO:1200365',
#     'NANDO:1200922',
#     'NANDO:1200705',
#     'NANDO:2200074',
#     'NANDO:1200030'],
#    ['NANDO_1200461',
#     'NANDO_1200466',
#     'NANDO_1200851',
#     'NANDO_1200061',
#     'NANDO_1200315',
#     'NANDO_1200365',
#     'NANDO_1200922',
#     'NANDO_1200705',
#     'NANDO_2200074',
#     'NANDO_1200030']]},
#  'ncbigene': {'label': 'NCBI gene',
#   'catalog': 'nbdc00073',
#   'category': 'Gene',
#   'regex': '^(?<id>\\d+)$',
#   'prefix': 'http://identifiers.org/ncbigene/',
#   'examples': [['63962027',
#     '1046',
#     '63961921',
#     '102606930',
#     '100472895',
#     '407025',
#     '84148',
#     '88',
#     '31157',
#     '100463227']]},
#  'ncbiprotein': {'label': 'NCBI protein',
#   'catalog': 'nbdc00584',
#   'category': 'Protein',
#   'regex': '^(?:(?:\\w+\\d+(?:\\.\\d+)?)|(?:NP_\\d+))$',
#   'prefix': 'http://identifiers.org/ncbiprotein/'},
#  'ncit_disease': {'label': 'NCIT disease',
#   'catalog': 'FIXME',
#   'category': 'Disease',
#   'regex': '^NCIT?[:_](?<id>C\\d+)$',
#   'prefix': 'http://purl.obolibrary.org/obo/NCIT_',
#   'format': ['NCIT:%s', 'NCIT_%s', 'NCI:%s', 'NCI_%s'],
#   'examples': [['NCIT:C48829',
#     'NCIT:C136825',
#     'NCIT:C48613',
#     'NCIT:C122795',
#     'NCIT:C67107',
#     'NCIT:C8417',
#     'NCIT:C8936',
#     'NCIT:C8644',
#     'NCIT:C80331',
#     'NCIT:C80342'],
#    ['NCIT_C48829',
#     'NCIT_C136825',
#     'NCIT_C48613',
#     'NCIT_C122795',
#     'NCIT_C67107',
#     'NCIT_C8417',
#     'NCIT_C8936',
#     'NCIT_C8644',
#     'NCIT_C80331',
#     'NCIT_C80342'],
#    ['NCI:C48829',
#     'NCI:C136825',
#     'NCI:C48613',
#     'NCI:C122795',
#     'NCI:C67107',
#     'NCI:C8417',
#     'NCI:C8936',
#     'NCI:C8644',
#     'NCI:C80331',
#     'NCI:C80342'],
#    ['NCI_C48829',
#     'NCI_C136825',
#     'NCI_C48613',
#     'NCI_C122795',
#     'NCI_C67107',
#     'NCI_C8417',
#     'NCI_C8936',
#     'NCI_C8644',
#     'NCI_C80331',
#     'NCI_C80342']]},
#  'ncit_tissue': {'label': 'NCIT tissue',
#   'catalog': 'FIXME',
#   'category': 'Tissue',
#   'regex': '^NCIT?[:_](?<id>C\\d+)$',
#   'prefix': 'http://purl.obolibrary.org/obo/NCIT_',
#   'format': ['NCIT:%s', 'NCIT_%s', 'NCI:%s', 'NCI_%s'],
#   'examples': [['NCIT:C12279',
#     'NCIT:C94820',
#     'NCIT:C77674',
#     'NCIT:C32082',
#     'NCIT:C12971',
#     'NCIT:C34285',
#     'NCIT:C97112',
#     'NCIT:C105446',
#     'NCIT:C12846',
#     'NCIT:C12845'],
#    ['NCIT_C12279',
#     'NCIT_C94820',
#     'NCIT_C77674',
#     'NCIT_C32082',
#     'NCIT_C12971',
#     'NCIT_C34285',
#     'NCIT_C97112',
#     'NCIT_C105446',
#     'NCIT_C12846',
#     'NCIT_C12845'],
#    ['NCI:C12279',
#     'NCI:C94820',
#     'NCI:C77674',
#     'NCI:C32082',
#     'NCI:C12971',
#     'NCI:C34285',
#     'NCI:C97112',
#     'NCI:C105446',
#     'NCI:C12846',
#     'NCI:C12845'],
#    ['NCI_C12279',
#     'NCI_C94820',
#     'NCI_C77674',
#     'NCI_C32082',
#     'NCI_C12971',
#     'NCI_C34285',
#     'NCI_C97112',
#     'NCI_C105446',
#     'NCI_C12846',
#     'NCI_C12845']]},
#  'oma_group': {'label': 'OMA group',
#   'catalog': 'nbdc02221',
#   'category': 'Ortholog',
#   'regex': '^(?<id>[A-Z]+)$',
#   'prefix': 'http://identifiers.org/oma.grp/',
#   'examples': [['RVAAYKY',
#     'LFVHAIL',
#     'EMSPITC',
#     'NQSHFFA',
#     'AYTHYSY',
#     'PRPKYDP',
#     'WSRIHIV',
#     'DFGGWKI',
#     'FHVAHGE',
#     'PYVYVTH']]},
#  'oma_protein': {'label': 'OMA protein',
#   'catalog': 'nbdc02221',
#   'category': 'Protein',
#   'regex': '^(?<id>[A-Z]{3}[A-Z0-9]{2}[0-9]{5,6})$',
#   'prefix': 'http://identifiers.org/oma.protein/',
#   'examples': [['ACIB400217',
#     'ACIB400465',
#     'HUMAN00333',
#     'HUMAN01170',
#     'HUMAN00470',
#     'HUMAN03367',
#     'ACIB400486',
#     'HUMAN01061',
#     'HUMAN02190',
#     'HUMAN02112']]},
#  'omim_gene': {'label': 'OMIM gene',
#   'catalog': 'nbdc00154',
#   'category': 'Gene',
#   'regex': '^(?:O?MIM:)?(?<id>\\d{6})$',
#   'prefix': 'http://identifiers.org/mim/',
#   'format': ['%s', 'OMIM:%s', 'MIM:%s'],
#   'examples': [['604810',
#     '115460',
#     '608706',
#     '300181',
#     '102575',
#     '601280',
#     '602832',
#     '601604',
#     '177075',
#     '608977'],
#    ['OMIM:604810',
#     'OMIM:115460',
#     'OMIM:608706',
#     'OMIM:300181',
#     'OMIM:102575',
#     'OMIM:601280',
#     'OMIM:602832',
#     'OMIM:601604',
#     'OMIM:177075',
#     'OMIM:608977'],
#    ['MIM:604810',
#     'MIM:115460',
#     'MIM:608706',
#     'MIM:300181',
#     'MIM:102575',
#     'MIM:601280',
#     'MIM:602832',
#     'MIM:601604',
#     'MIM:177075',
#     'MIM:608977']]},
#  'omim_phenotype': {'label': 'OMIM phenotype',
#   'catalog': 'nbdc00154',
#   'category': 'Disease',
#   'regex': '^(?:O?MIM:)?(?<id>\\d{6})$',
#   'prefix': 'http://identifiers.org/mim/',
#   'format': ['%s', 'OMIM:%s', 'MIM:%s'],
#   'examples': [['207780',
#     '236100',
#     '237500',
#     '300716',
#     '125310',
#     '165199',
#     '617175',
#     '137600',
#     '600089',
#     '601317'],
#    ['OMIM:207780',
#     'OMIM:236100',
#     'OMIM:237500',
#     'OMIM:300716',
#     'OMIM:125310',
#     'OMIM:165199',
#     'OMIM:617175',
#     'OMIM:137600',
#     'OMIM:600089',
#     'OMIM:601317'],
#    ['MIM:207780',
#     'MIM:236100',
#     'MIM:237500',
#     'MIM:300716',
#     'MIM:125310',
#     'MIM:165199',
#     'MIM:617175',
#     'MIM:137600',
#     'MIM:600089',
#     'MIM:601317']]},
#  'orphanet': {'label': 'Orphanet',
#   'catalog': 'nbdc01422',
#   'category': 'Disease',
#   'regex': '^(?:ORPHA|ORDO|Orphanet)[:_](?<id>[A-Z0-9]+)$',
#   'prefix': 'http://identifiers.org/orphanet.ordo/Orphanet_',
#   'format': ['ORPHA:%s', 'ORDO:%s', 'Orphanet:%s', 'Orphanet_%s'],
#   'examples': [['ORPHA:101078',
#     'ORPHA:596',
#     'ORPHA:1934',
#     'ORPHA:1047',
#     'ORPHA:60025',
#     'ORPHA:166090',
#     'ORPHA:275745',
#     'ORPHA:1171',
#     'ORPHA:93277',
#     'ORPHA:247598'],
#    ['ORDO:101078',
#     'ORDO:596',
#     'ORDO:1934',
#     'ORDO:1047',
#     'ORDO:60025',
#     'ORDO:166090',
#     'ORDO:275745',
#     'ORDO:1171',
#     'ORDO:93277',
#     'ORDO:247598'],
#    ['Orphanet:101078',
#     'Orphanet:596',
#     'Orphanet:1934',
#     'Orphanet:1047',
#     'Orphanet:60025',
#     'Orphanet:166090',
#     'Orphanet:275745',
#     'Orphanet:1171',
#     'Orphanet:93277',
#     'Orphanet:247598'],
#    ['Orphanet_101078',
#     'Orphanet_596',
#     'Orphanet_1934',
#     'Orphanet_1047',
#     'Orphanet_60025',
#     'Orphanet_166090',
#     'Orphanet_275745',
#     'Orphanet_1171',
#     'Orphanet_93277',
#     'Orphanet_247598']]},
#  'pdb': {'label': 'PDB',
#   'catalog': 'nbdc00156',
#   'category': 'Structure',
#   'regex': '^(?<id>[0-9][A-Za-z0-9]{3})$',
#   'prefix': 'http://rdf.wwpdb.org/pdb/',
#   'examples': [['3PFQ',
#     '2OUY',
#     '6EBX',
#     '5GHP',
#     '6ETH',
#     '1Y28',
#     '6FB2',
#     '5JO3',
#     '2JQZ',
#     '5L5P'],
#    ['3pfq',
#     '2ouy',
#     '6ebx',
#     '5ghp',
#     '6eth',
#     '1y28',
#     '6fb2',
#     '5jo3',
#     '2jqz',
#     '5l5p']]},
#  'pfam': {'label': 'Pfam',
#   'catalog': 'nbdc00163',
#   'category': 'Domain',
#   'regex': '^(?<id>PF\\d{5})$',
#   'prefix': 'http://identifiers.org/pfam/',
#   'examples': [['PF03719',
#     'PF03726',
#     'PF02809',
#     'PF00105',
#     'PF00250',
#     'PF00412',
#     'PF01412',
#     'PF00459',
#     'PF02532',
#     'PF01226']]},
#  'pubchem_compound': {'label': 'PubChem compound',
#   'catalog': 'nbdc00641',
#   'category': 'Compound',
#   'regex': '^(?:CID)?(?<id>\\d+)$',
#   'prefix': 'http://rdf.ncbi.nlm.nih.gov/pubchem/compound/CID',
#   'format': ['%s', 'CID%s'],
#   'examples': [['9548669',
#     '160419',
#     '9869929',
#     '76333303',
#     '9868491',
#     '27854',
#     '76329169',
#     '3448',
#     '296',
#     '10371227'],
#    ['CID9548669',
#     'CID160419',
#     'CID9869929',
#     'CID76333303',
#     'CID9868491',
#     'CID27854',
#     'CID76329169',
#     'CID3448',
#     'CID296',
#     'CID10371227']]},
#  'pubchem_substance': {'label': 'PubChem substance',
#   'catalog': 'nbdc00642',
#   'category': 'Compound',
#   'regex': '^(?:SID)?(?<id>\\d+)$',
#   'prefix': 'http://rdf.ncbi.nlm.nih.gov/pubchem/substance/SID',
#   'format': ['%s', 'SID%s'],
#   'examples': [['15229855',
#     '15277848',
#     '15782795',
#     '16076657',
#     '16035895',
#     '12012900',
#     '15378994',
#     '14850434',
#     '14847540',
#     '15271473'],
#    ['SID15229855',
#     'SID15277848',
#     'SID15782795',
#     'SID16076657',
#     'SID16035895',
#     'SID12012900',
#     'SID15378994',
#     'SID14850434',
#     'SID14847540',
#     'SID15271473']]},
#  'pubchem_pathway': {'label': 'PubChem pathway',
#   'catalog': 'nbdc02626',
#   'category': 'Pathway',
#   'regex': '^(?:PWID)?(?<id>\\d+)$',
#   'prefix': 'http://rdf.ncbi.nlm.nih.gov/pubchem/pathway/PWID',
#   'format': ['%s', 'PWID%s'],
#   'examples': [['10572',
#     '1',
#     '10576',
#     '10577',
#     '10579',
#     '10573',
#     '10582',
#     '10574',
#     '10575',
#     '10581'],
#    ['PWID10572',
#     'PWID1',
#     'PWID10576',
#     'PWID10577',
#     'PWID10579',
#     'PWID10573',
#     'PWID10582',
#     'PWID10574',
#     'PWID10575',
#     'PWID10581']]},
#  'pubmed': {'label': 'PubMed',
#   'catalog': 'nbdc00179',
#   'category': 'Literature',
#   'regex': '^(?:pmid:|PMID:)?(?<id>\\d+)$',
#   'prefix': 'http://rdf.ncbi.nlm.nih.gov/pubmed/',
#   'format': ['%s', 'pmid:%s', 'PMID:%s'],
#   'examples': [['19281226',
#     '19879151',
#     '20858243',
#     '10773016',
#     '16527252',
#     '28499733',
#     '10397770',
#     '15149666',
#     '23861362',
#     '10577920'],
#    ['pmid:19281226',
#     'pmid:19879151',
#     'pmid:20858243',
#     'pmid:10773016',
#     'pmid:16527252',
#     'pmid:28499733',
#     'pmid:10397770',
#     'pmid:15149666',
#     'pmid:23861362',
#     'pmid:10577920'],
#    ['PMID:19281226',
#     'PMID:19879151',
#     'PMID:20858243',
#     'PMID:10773016',
#     'PMID:16527252',
#     'PMID:28499733',
#     'PMID:10397770',
#     'PMID:15149666',
#     'PMID:23861362',
#     'PMID:10577920']]},
#  'reactome_pathway': {'label': 'Reactome pathway',
#   'catalog': 'nbdc00185',
#   'category': 'Pathway',
#   'regex': '^(?<id>R-[A-Z]{3}-\\d+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/reactome/',
#   'examples': [['R-HSA-165159',
#     'R-DRE-1630316',
#     'R-SCE-9634635',
#     'R-DRE-140834',
#     'R-HSA-2142753',
#     'R-BTA-383280',
#     'R-MMU-5218900',
#     'R-RNO-5654219',
#     'R-MMU-8875791',
#     'R-MMU-9648025']]},
#  'reactome_reaction': {'label': 'Reactome reaction',
#   'catalog': 'nbdc00185',
#   'category': 'Reaction',
#   'regex': '^(?<id>R-[A-Z]{3}-\\d+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/reactome/',
#   'examples': [['R-DRE-1482961',
#     'R-DRE-6814409',
#     'R-HSA-2395869',
#     'R-HSA-1222722',
#     'R-HSA-893583',
#     'R-MMU-158484',
#     'R-HSA-8875071',
#     'R-HSA-372519',
#     'R-HSA-6797627',
#     'R-DRE-975814']]},
#  'refseq_genomic': {'label': 'RefSeq genomic',
#   'catalog': 'nbdc00187',
#   'category': 'Gene',
#   'regex': '^(?<id>(?:AC_|N[CGTW]_|NZ_[A-Z]+)\\d+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/refseq/',
#   'examples': [['NG_004671',
#     'NG_011844',
#     'NG_008481',
#     'NG_007973',
#     'NG_001091',
#     'NG_008005',
#     'NG_023230',
#     'NG_046394',
#     'NG_009617',
#     'NG_016421',
#     'NG_021472'],
#    ['NG_004671.3',
#     'NG_011844.2',
#     'NG_008481.4',
#     'NG_007973.1',
#     'NG_001091.7',
#     'NG_008005.1',
#     'NG_023230.1',
#     'NG_046394.1',
#     'NG_009617.1',
#     'NG_016421.2',
#     'NG_021472.2']]},
#  'refseq_protein': {'label': 'RefSeq protein',
#   'catalog': 'nbdc00187',
#   'category': 'Protein',
#   'regex': '^(?<id>[ANXYWZ]P_\\d+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/refseq/',
#   'examples': [['NP_001171968',
#     'NP_001365494',
#     'NP_000015',
#     'XP_011522750',
#     'XP_011516190',
#     'XP_005265876',
#     'WP_016919164',
#     'WP_080513319',
#     'YP_001687722',
#     'YP_001966380'],
#    ['NP_001171968.1',
#     'NP_001365494.1',
#     'NP_000015.2',
#     'XP_011522750.1',
#     'XP_011516190.1',
#     'XP_005265876.1',
#     'WP_016919164.1',
#     'WP_080513319.1',
#     'YP_001687722.1',
#     'YP_001966380.1']]},
#  'refseq_rna': {'label': 'RefSeq RNA',
#   'catalog': 'nbdc00187',
#   'category': 'Transcript',
#   'regex': '^(?<id>(?:NM|NR|XM|XR)_\\d+)(?:\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/refseq/',
#   'examples': [['XR_001747779',
#     'XM_017013006',
#     'NM_001199636',
#     'XM_011532496',
#     'NM_001110',
#     'NR_170162',
#     'NM_020113',
#     'NM_001031805',
#     'NR_027673',
#     'XR_934019'],
#    ['XR_001747779.1',
#     'XM_017013006.1',
#     'NM_001199636.2',
#     'XM_011532496.1',
#     'NM_001110.4',
#     'NR_170162.1',
#     'NM_020113.3',
#     'NM_001031805.1',
#     'NR_027673.1',
#     'XR_934019.3']]},
#  'rgd': {'label': 'RGD',
#   'catalog': 'nbdc00188',
#   'category': 'Gene',
#   'regex': '^(?:(?:RGD|rgd):)?(?<id>\\d{4,})$',
#   'prefix': 'http://identifiers.org/rgd/',
#   'format': ['%s', 'RGD:%s', 'rgd:%s'],
#   'examples': [['1308312',
#     '1311120',
#     '1309724',
#     '1565514',
#     '7683241',
#     '1307957',
#     '71036',
#     '1307876',
#     '1308965',
#     '1305482'],
#    ['RGD:1308312',
#     'RGD:1311120',
#     'RGD:1309724',
#     'RGD:1565514',
#     'RGD:7683241',
#     'RGD:1307957',
#     'RGD:71036',
#     'RGD:1307876',
#     'RGD:1308965',
#     'RGD:1305482'],
#    ['rgd:1308312',
#     'rgd:1311120',
#     'rgd:1309724',
#     'rgd:1565514',
#     'rgd:7683241',
#     'rgd:1307957',
#     'rgd:71036',
#     'rgd:1307876',
#     'rgd:1308965',
#     'rgd:1305482']]},
#  'rhea': {'label': 'Rhea',
#   'catalog': 'nbdc02083',
#   'category': 'Reaction',
#   'regex': '^(?<id>\\d{5})$',
#   'prefix': 'http://identifiers.org/rhea/',
#   'examples': [['10253',
#     '10818',
#     '13517',
#     '11136',
#     '13729',
#     '10240',
#     '11728',
#     '16870',
#     '10732',
#     '11278']]},
#  'sgd': {'label': 'SGD',
#   'catalog': 'nbdc00202',
#   'category': 'Gene',
#   'regex': '^(?<id>S\\d{9})$',
#   'prefix': 'http://identifiers.org/sgd/',
#   'examples': [['S000003096',
#     'S000003789',
#     'S000005770',
#     'S000028467',
#     'S000006377',
#     'S000001180',
#     'S000003769',
#     'S000001459',
#     'S000004428',
#     'S000006021']]},
#  'sra_accession': {'label': 'SRA accession',
#   'catalog': 'nbdc00687',
#   'category': 'Submission',
#   'regex': '^(?<id>[SED]RA\\d+)$',
#   'prefix': 'http://identifiers.org/insdc.sra/',
#   'examples': [['DRA000741',
#     'DRA000768',
#     'DRA001014',
#     'DRA000833',
#     'SRA000144',
#     'SRA000605',
#     'SRA008879',
#     'ERA007227',
#     'ERA011638',
#     'ERA013580']]},
#  'sra_analysis': {'label': 'SRA analysis',
#   'catalog': 'nbdc00687',
#   'category': 'Analysis',
#   'regex': '^(?<id>[SED]RZ\\d+)$',
#   'prefix': 'http://identifiers.org/insdc.sra/',
#   'examples': [['DRZ000249',
#     'DRZ000087',
#     'DRZ003045',
#     'DRZ000829',
#     'SRZ168127',
#     'SRZ008405',
#     'SRZ010259',
#     'SRZ011419',
#     'SRZ006662',
#     'SRZ010567']]},
#  'sra_experiment': {'label': 'SRA experiment',
#   'catalog': 'nbdc00687',
#   'category': 'Experiment',
#   'regex': '^(?<id>[SED]RX\\d+)$',
#   'prefix': 'http://identifiers.org/insdc.sra/',
#   'examples': [['DRX000585',
#     'DRX000114',
#     'DRX000613',
#     'DRX000681',
#     'SRX000921',
#     'SRX000254',
#     'SRX000626',
#     'ERX149204',
#     'ERX001260',
#     'ERX000427']]},
#  'sra_project': {'label': 'SRA project',
#   'catalog': 'nbdc00687',
#   'category': 'Project',
#   'regex': '^(?<id>[SED]RP\\d+)$',
#   'prefix': 'http://identifiers.org/insdc.sra/',
#   'examples': [['DRP000994',
#     'DRP000877',
#     'DRP000649',
#     'DRP000147',
#     'SRP266466',
#     'SRP297268',
#     'SRP000065',
#     'ERP001266',
#     'ERP007720',
#     'ERP104141']]},
#  'sra_run': {'label': 'SRA run',
#   'catalog': 'nbdc00687',
#   'category': 'SequenceRun',
#   'regex': '^(?<id>[SED]RR\\d+)$',
#   'prefix': 'http://identifiers.org/insdc.sra/',
#   'examples': [['DRR000834',
#     'DRR000683',
#     'DRR000264',
#     'DRR000453',
#     'SRR029947',
#     'SRR000290',
#     'SRR004854',
#     'ERR499402',
#     'ERR004130',
#     'ERR000715']]},
#  'sra_sample': {'label': 'SRA sample',
#   'catalog': 'nbdc00687',
#   'category': 'Sample',
#   'regex': '^(?<id>[SED]RS\\d+)$',
#   'prefix': 'http://identifiers.org/insdc.sra/',
#   'examples': [['DRS001431',
#     'DRS001371',
#     'DRS000894',
#     'DRS000386',
#     'SRS2618009',
#     'SRS7846025',
#     'SRS000159',
#     'ERS452503',
#     'ERS000126',
#     'ERS010423']]},
#  'swisslipids': {'label': 'SwissLipids',
#   'catalog': 'nbdc02026',
#   'category': 'Lipids',
#   'regex': '^SLM:(?<id>\\d+)$',
#   'prefix': 'http://identifiers.org/slm/SLM:',
#   'examples': [['SLM:000000002',
#     'SLM:000000003',
#     'SLM:000000006',
#     'SLM:000000007',
#     'SLM:000000035',
#     'SLM:000000042',
#     'SLM:000000043',
#     'SLM:000000044',
#     'SLM:000000047',
#     'SLM:000000048']]},
#  'tair': {'label': 'TAIR',
#   'catalog': 'nbdc00697',
#   'category': 'Gene',
#   'regex': '^(?<id>AT.G\\d{5})(\\.\\d+)?$',
#   'prefix': 'http://identifiers.org/tair.name/',
#   'examples': [['AT3G60400',
#     'AT1G26300',
#     'AT2G03160',
#     'AT1G25340',
#     'AT3G22470',
#     'AT3G58030',
#     'AT2G42680',
#     'AT4G05600',
#     'AT2G47480',
#     'AT4G30420']]},
#  'taxonomy': {'label': 'Taxonomy',
#   'catalog': 'nbdc00700',
#   'category': 'Organism',
#   'regex': '^(?<id>\\d+)$',
#   'prefix': 'http://identifiers.org/taxonomy/',
#   'examples': [['1171376',
#     '484906',
#     '1214242',
#     '1124991',
#     '1037911',
#     '1266844',
#     '243277',
#     '696747',
#     '263820',
#     '713604']]},
#  'togovar': {'label': 'TogoVar variant',
#   'catalog': 'nbdc02359',
#   'category': 'Variant',
#   'regex': '^(?<id>tgv\\d+)$',
#   'prefix': 'http://identifiers.org/togovar/',
#   'examples': [['tgv100005930',
#     'tgv100000890',
#     'tgv16331',
#     'tgv10000341',
#     'tgv21330879',
#     'tgv15847',
#     'tgv1354996',
#     'tgv100002132',
#     'tgv16568524',
#     'tgv62035164']]},
#  'uberon': {'label': 'UBERON',
#   'catalog': 'FIXME',
#   'category': 'Tissue',
#   'regex': '^UBERON[:_](?<id>\\d{7})$',
#   'prefix': 'http://purl.obolibrary.org/obo/UBERON_',
#   'format': ['UBERON:%s', 'UBERON_%s'],
#   'examples': [['UBERON:0002115',
#     'UBERON:0001004',
#     'UBERON:0000007',
#     'UBERON:0001044',
#     'UBERON:0001825',
#     'UBERON:0001361',
#     'UBERON:0002186',
#     'UBERON:0000945',
#     'UBERON:0036068',
#     'UBERON:0001017'],
#    ['UBERON_0002115',
#     'UBERON_0001004',
#     'UBERON_0000007',
#     'UBERON_0001044',
#     'UBERON_0001825',
#     'UBERON_0001361',
#     'UBERON_0002186',
#     'UBERON_0000945',
#     'UBERON_0036068',
#     'UBERON_0001017']]},
#  'uniprot': {'label': 'UniProt',
#   'catalog': 'nbdc00221',
#   'category': 'Protein',
#   'regex': '^(?:(?<id1>[A-NR-Z][0-9](?:[A-Z][A-Z0-9][A-Z0-9][0-9]){1,2}(?:-\\d+)?)|(?<id2>[OPQ][0-9][A-Z0-9][A-Z0-9][A-Z0-9][0-9](?:-\\d+)?)(?:\\.\\d+)?)$',
#   'prefix': 'http://purl.uniprot.org/uniprot/',
#   'examples': [['A0A174V9D2',
#     'A0A1V4U2Y9',
#     'Q7NXD4',
#     'P0AAM3',
#     'O43423',
#     'D4IJI4',
#     'Q66SS1',
#     'B5IDU9',
#     'D3TBR4',
#     'D4ILS5']]},
#  'uniprot_mnemonic': {'label': 'UniProt mnemonic',
#   'catalog': 'nbdc00221',
#   'category': 'Protein',
#   'regex': '^(?<id>[A-Z0-9]+_[A-Z0-9]{0,5})$',
#   'prefix': 'http://purl.uniprot.org/uniprot/',
#   'examples': [['2ABA_ORYSJ',
#     '33K_ADES1',
#     '1003L_ASFK5',
#     '1A1D_VARPS',
#     '1B02_GORGO',
#     '1003L_ASFP4',
#     '1433B_MACFA',
#     '1107L_ASFWA',
#     '3BHS1_MOUSE',
#     '14331_SCHMA']]},
#  'uniprot_reference_proteome': {'label': 'UniProt reference proteome',
#   'catalog': 'nbdc00221',
#   'category': 'Proteome',
#   'regex': '^(?<id>UP\\d{0,9})$',
#   'prefix': 'http://purl.uniprot.org/proteomes/',
#   'examples': [['UP000005640',
#     'UP000002311',
#     'UP000005640',
#     'UP000000589',
#     'UP000000803',
#     'UP000000437',
#     'UP000001819',
#     'UP000008028',
#     'UP000008143',
#     'UP000079169']]},
#  'vgnc': {'label': 'VGNC',
#   'catalog': 'nbdc02624',
#   'category': 'Gene',
#   'regex': '^((VGNC|vgnc):)?(?<id>\\d{1,9})$',
#   'format': ['%s', 'VGNC:%s', 'vgnc:%s'],
#   'prefix': 'http://identifiers.org/vgnc/',
#   'examples': [['39230',
#     '49608',
#     '85188',
#     '76040',
#     '72808',
#     '73601',
#     '9436',
#     '78821',
#     '74596',
#     '5304'],
#    ['VGNC:39230',
#     'VGNC:49608',
#     'VGNC:85188',
#     'VGNC:76040',
#     'VGNC:72808',
#     'VGNC:73601',
#     'VGNC:9436',
#     'VGNC:78821',
#     'VGNC:74596',
#     'VGNC:5304'],
#    ['vgnc:39230',
#     'vgnc:49608',
#     'vgnc:85188',
#     'vgnc:76040',
#     'vgnc:72808',
#     'vgnc:73601',
#     'vgnc:9436',
#     'vgnc:78821',
#     'vgnc:74596',
#     'vgnc:5304']]},
#  'wikipathways': {'label': 'WikiPathways',
#   'catalog': 'nbdc02116',
#   'category': 'Pathway',
#   'regex': '^(?<id>WP\\d{1,5})(?:\\_r\\d+)?$',
#   'prefix': 'http://identifiers.org/wikipathways/',
#   'examples': [['WP1531',
#     'WP4312',
#     'WP4877',
#     'WP5020',
#     'WP4400',
#     'WP4474',
#     'WP4183',
#     'WP3650',
#     'WP4545',
#     'WP4462'],
#    ['WP1531_r107120',
#     'WP4312_r104287',
#     'WP4877_r116595',
#     'WP5020_r114721',
#     'WP4400_r108112',
#     'WP4474_r102094',
#     'WP4183_r106890',
#     'WP3650_r110699',
#     'WP4545_r116235',
#     'WP4462_r102079']]},
#  'wormbase_gene': {'label': 'WormBase gene',
#   'catalog': 'nbdc00740',
#   'category': 'Gene',
#   'regex': '^(?<id>WBGene\\d{8})$',
#   'prefix': 'http://identifiers.org/wb/',
#   'examples': [['WBGene00016754',
#     'WBGene00015101',
#     'WBGene00186327',
#     'WBGene00061034',
#     'WBGene00053829',
#     'WBGene00084107',
#     'WBGene00073019',
#     'WBGene00018190',
#     'WBGene00011286',
#     'WBGene00062378']]},
#  'xenbase_gene': {'label': 'Xenbase gene',
#   'catalog': 'nbdc01892',
#   'category': 'Gene',
#   'regex': '^(?<id>XB\\-[A-Z]+\\-\\d+)$',
#   'prefix': 'http://identifiers.org/xenbase/',
#   'examples': [['XB-GENE-877040',
#     'XB-GENE-22060981',
#     'XB-GENE-17344257',
#     'XB-GENE-487684',
#     'XB-GENE-1014349',
#     'XB-GENE-17335133',
#     'XB-GENE-1012537',
#     'XB-GENE-494019',
#     'XB-GENE-5952945',
#     'XB-GENE-957742']]},
#  'zfin_gene': {'label': 'ZFIN gene',
#   'catalog': 'nbdc00746',
#   'category': 'Gene',
#   'regex': '^(?<id>ZDB\\-[A-Z]+\\-\\d{6}\\-\\d+)$',
#   'prefix': 'http://identifiers.org/zfin/',
#   'examples': [['ZDB-GENE-030131-9947',
#     'ZDB-GENE-030131-2670',
#     'ZDB-GENE-060929-100',
#     'ZDB-GENE-011101-3',
#     'ZDB-GENE-050411-94',
#     'ZDB-GENE-080204-28',
#     'ZDB-GENE-070424-32',
#     'ZDB-GENE-011205-22',
#     'ZDB-GENE-030131-3788',
#     'ZDB-GENE-130530-940']]}}

# %%
dataset_color = {}
for ds in dataset_config:
    cat = dataset_config[ds]['category']
    if not cat in categories_color:
        continue
    dataset_color[ds] = categories_color[cat]['color']

dataset_color
# Out:
# {'affy_probeset': '#53c666',
#  'bioproject': '#696969',
#  'biosample': '#696969',
#  'ccds': '#53c666',
#  'chebi': '#a853c6',
#  'chembl_compound': '#a853c6',
#  'chembl_target': '#a2c653',
#  'civic_gene': '#53c666',
#  'clinvar': '#53c3c6',
#  'dbsnp': '#53c3c6',
#  'dgidb': '#c65381',
#  'doid': '#5361c6',
#  'drugbank': '#a853c6',
#  'ec': '#696969',
#  'ena': '#53c666',
#  'ensembl_gene': '#53c666',
#  'ensembl_protein': '#a2c653',
#  'ensembl_transcript': '#53c666',
#  'flybase_gene': '#53c666',
#  'gea': '#696969',
#  'glytoucan': '#673aa6',
#  'go': '#696969',
#  'hgnc': '#53c666',
#  'hgnc_symbol': '#53c666',
#  'hmdb': '#a853c6',
#  'homologene': '#53c666',
#  'cog': '#53c666',
#  'hp': '#5361c6',
#  'human_protein_atlas': '#a2c653',
#  'inchi_key': '#a853c6',
#  'insdc': '#53c666',
#  'insdc_master': '#696969',
#  'intact': '#c65381',
#  'interpro': '#a2c653',
#  'kegg_compound': '#a853c6',
#  'kegg_disease': '#5361c6',
#  'kegg_orthology': '#53c666',
#  'kegg_pathway': '#c65381',
#  'kegg_reaction': '#c65381',
#  'lrg': '#53c666',
#  'mbgd_gene': '#53c666',
#  'meddra': '#5361c6',
#  'medgen': '#5361c6',
#  'mesh': '#5361c6',
#  'mgi': '#53c666',
#  'mirbase': '#53c666',
#  'mondo': '#5361c6',
#  'nando': '#5361c6',
#  'ncbigene': '#53c666',
#  'ncbiprotein': '#a2c653',
#  'ncit_disease': '#5361c6',
#  'oma_group': '#53c666',
#  'oma_protein': '#a2c653',
#  'omim_gene': '#53c666',
#  'omim_phenotype': '#5361c6',
#  'orphanet': '#5361c6',
#  'pdb': '#c68753',
#  'pfam': '#a2c653',
#  'pubchem_compound': '#a853c6',
#  'pubchem_substance': '#a853c6',
#  'pubchem_pathway': '#c65381',
#  'pubmed': '#696969',
#  'reactome_pathway': '#c65381',
#  'reactome_reaction': '#c65381',
#  'refseq_genomic': '#53c666',
#  'refseq_protein': '#a2c653',
#  'refseq_rna': '#53c666',
#  'rgd': '#53c666',
#  'rhea': '#c65381',
#  'sgd': '#53c666',
#  'sra_accession': '#696969',
#  'sra_analysis': '#696969',
#  'sra_experiment': '#696969',
#  'sra_project': '#696969',
#  'sra_run': '#696969',
#  'sra_sample': '#696969',
#  'tair': '#53c666',
#  'togovar': '#53c3c6',
#  'uniprot': '#a2c653',
#  'uniprot_mnemonic': '#a2c653',
#  'vgnc': '#53c666',
#  'wikipathways': '#c65381',
#  'wormbase_gene': '#53c666',
#  'xenbase_gene': '#53c666',
#  'zfin_gene': '#53c666'}

# %% [markdown]
# ### PyVis init

# %%
net = Network(notebook=True, cdn_resources='in_line', bgcolor='gray', font_color='white')

# %% [markdown]
# ### Add hub node (primary dataset) and connected nodes (attributes added by togodx)

# %%
for oid in id_pairs['orig_id'].drop_duplicates():
    net.add_node(oid, color='white')

# %%
for did in id_pairs['dest_id'].drop_duplicates():
    ds = did.split(':')[0]
    color = dataset_color[ds]
    net.add_node(did, color=color)

# %%
net.add_edges(id_pairs.to_numpy())

# %%
net.toggle_physics(True)
net.show('mygraph.html')
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="mygraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
outer_entries = subset[subset['dest_dataset'] != subset['orig_dataset'][0] ][['dest_dataset', 'dest_entry']].drop_duplicates()
outer_entries
# Out:
#           dest_dataset       dest_entry
# 0   ensembl_transcript  ENST00000379939
# 1   ensembl_transcript  ENST00000400445
# 2   ensembl_transcript  ENST00000537702
# 3   ensembl_transcript  ENST00000629018
# 4             ncbigene            26960
# 8              uniprot       A0A0D9SF28
# 9              uniprot       A0A8I5KQL6
# 10             uniprot       A0A8I5KQP5
# 11             uniprot       A0A8I5KRX1
# 12             uniprot       A0A8I5KRZ1
# 13             uniprot       A0A8I5KS18
# 14             uniprot       A0A8I5KS58
# 15             uniprot       A0A8I5KSX3
# 16             uniprot       A0A8I5KTV6
# 17             uniprot       A0A8I5KTY1
# 18             uniprot       A0A8I5KWL1
# 19             uniprot       A0A8I5KX92
# 20             uniprot       A0A8I5KXL4
# 21             uniprot       A0A8I5KXR7
# 22             uniprot       A0A8I5KXW8
# 23             uniprot       A0A8I5KXY8
# 24             uniprot       A0A8I5KZ13
# 25             uniprot       A0A8I5QJB2
# 26             uniprot       A0A8I5QJQ0
# 27             uniprot       A0A8I5QKR1
# 28             uniprot       A0A8I5QKR6
# 29             uniprot           Q5T321
# 30             uniprot           Q8NFP9
# 79               mondo          0030930

# %%
attributes_json_url = 'https://github.com/togodx/togodx-config-human/raw/develop/config/attributes.dx-server.json'
attributes_json = json.loads(urlopen(attributes_json_url).read())
datasets_dict = attributes_json['datasets']
datasets_dict
# Out:
# {'ensembl_gene': {'label': 'Ensembl gene',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/ensembl_gene.hbs',
#   'target': True,
#   'examples': ['ENSG00000148584',
#    'ENSG00000164398',
#    'ENSG00000127914',
#    'ENSG00000117020',
#    'ENSG00000111275',
#    'ENSG00000029534',
#    'ENSG00000078061',
#    'ENSG00000100852',
#    'ENSG00000104728',
#    'ENSG00000074964',
#    'ENSG00000143970',
#    'ENSG00000198604',
#    'ENSG00000126453',
#    'ENSG00000029363',
#    'ENSG00000115760',
#    'ENSG00000112175',
#    'ENSG00000159388',
#    'ENSG00000261652',
#    'ENSG00000164305',
#    'ENSG00000132906',
#    'ENSG00000112237',
#    'ENSG00000183813',
#    'ENSG00000126353',
#    'ENSG00000090659',
#    'ENSG00000178562',
#    'ENSG00000040731',
#    'ENSG00000079112',
#    'ENSG00000124762',
#    'ENSG00000121289',
#    'ENSG00000173575',
#    'ENSG00000109220',
#    'ENSG00000171310',
#    'ENSG00000172409',
#    'ENSG00000176571',
#    'ENSG00000174469',
#    'ENSG00000168542',
#    'ENSG00000164919',
#    'ENSG00000107864',
#    'ENSG00000101343',
#    'ENSG00000182578',
#    'ENSG00000164796',
#    'ENSG00000044115',
#    'ENSG00000066032',
#    'ENSG00000198561',
#    'ENSG00000169862',
#    'ENSG00000036257',
#    'ENSG00000138115',
#    'ENSG00000152207',
#    'ENSG00000198354',
#    'ENSG00000187323',
#    'ENSG00000128191',
#    'ENSG00000280757',
#    'ENSG00000203734',
#    'ENSG00000074266',
#    'ENSG00000173674',
#    'ENSG00000163435',
#    'ENSG00000049540',
#    'ENSG00000044524',
#    'ENSG00000135333',
#    'ENSG00000168040',
#    'ENSG00000159784',
#    'ENSG00000147724',
#    'ENSG00000198173',
#    'ENSG00000165323',
#    'ENSG00000163520',
#    'ENSG00000168496',
#    'ENSG00000122642',
#    'ENSG00000196924',
#    'ENSG00000187239',
#    'ENSG00000176302',
#    'ENSG00000111087',
#    'ENSG00000163655',
#    'ENSG00000113384',
#    'ENSG00000179399',
#    'ENSG00000198822',
#    'ENSG00000179362',
#    'ENSG00000117318',
#    'ENSG00000073792',
#    'ENSG00000175329',
#    'ENSG00000138448',
#    'ENSG00000153814',
#    '4958',
#    '26986',
#    '5093',
#    '5378',
#    '5428',
#    '5430',
#    '7799',
#    '5579',
#    '5587',
#    '25766',
#    '5777',
#    '5789',
#    '114825',
#    '5884',
#    '5900',
#    '55159',
#    '653489',
#    '6000',
#    '6092',
#    '6278',
#    '5413',
#    '23157',
#    '10801',
#    '23067',
#    '9869',
#    '6446',
#    '57698',
#    '140885',
#    '10736',
#    '6497',
#    '6602',
#    '8243',
#    '92017',
#    '11166',
#    '92521',
#    '9901',
#    '10274',
#    '10923',
#    '7006',
#    '29844',
#    '7037',
#    '9967',
#    '7114',
#    '3371',
#    '84101',
#    '8239',
#    '7409',
#    '143187',
#    '65268',
#    '55596',
#    '6935',
#    '9203',
#    '353088',
#    '90827',
#    '84133'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot,reactome_reaction,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot,reactome_reaction,chebi,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,mondo,nando&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot,reactome_reaction,chebi,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot&ids='}},
#  'uniprot': {'label': 'UniProt',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/uniprot.hbs',
#   'target': True,
#   'examples': ['P10275',
#    'P18846',
#    'P49715',
#    'P16220',
#    'P03372',
#    'Q01844',
#    'Q12778',
#    'P15976',
#    'P23771',
#    'P20823',
#    'P35680',
#    'Q13422',
#    'P10914',
#    'Q15306',
#    'Q99612',
#    'P25800',
#    'P12980',
#    'P01106',
#    'Q92570',
#    'P23760',
#    'Q02548',
#    'P23759',
#    'P40424',
#    'Q99453',
#    'P29590',
#    'Q01196',
#    'Q13485',
#    'O15105',
#    'P51692',
#    'P17542',
#    'Q12888',
#    'P19544',
#    'Q05516'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,reactome_reaction,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,reactome_reaction,chebi,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,reactome_reaction,chebi,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,hgnc,togovar&ids='}},
#  'pdb': {'label': 'PDB',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/pdb.hbs',
#   'target': True,
#   'examples': ['1T09', '2N9C', '1G3J', '2ENQ', '1DD1'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,reactome_reaction,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,reactome_reaction,chebi,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen,mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,ncbigene,medgen,orphanet&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,reactome_reaction,chebi,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot,hgnc,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=pdb,uniprot&ids='}},
#  'chebi': {'label': 'ChEBI compound',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/chebi.hbs',
#   'target': True,
#   'examples': ['3128', '9927', '4785', '9589', '32301', '2668', '9637'],
#   'conversion': {'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,uniprot,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,pubchem_compound,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,uniprot,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound,mesh,mondo,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound,mesh,mondo,medgen,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,uniprot,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,chembl_compound,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,uniprot,hgnc,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=chebi,reactome_reaction,uniprot&ids='}},
#  'chembl_compound': {'label': 'ChEMBL compound',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/chembl_compound.hbs',
#   'target': True,
#   'examples': ['CHEMBL1472989',
#    'CHEMBL1069',
#    'CHEMBL578',
#    'CHEMBL1717',
#    'CHEMBL1200772',
#    'CHEMBL1491',
#    'CHEMBL1148'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,uniprot,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,pubchem_compound,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,uniprot,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh,mondo,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh,mondo,medgen,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,uniprot,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,mesh,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,uniprot,hgnc,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=chembl_compound,chebi,reactome_reaction,uniprot&ids='}},
#  'pubchem_compound': {'label': 'PubChem compound',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/pubchem_compound.hbs',
#   'target': True,
#   'examples': ['135398633',
#    '15938971',
#    '936',
#    '1061',
#    '5461108',
#    '7058055',
#    '271',
#    '32051'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,uniprot,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,uniprot,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh,mondo,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh,mondo,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh,mondo,medgen,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,uniprot,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh,mondo,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chembl_compound,mesh,mondo,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,uniprot,pdb&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,uniprot,hgnc,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=pubchem_compound,chebi,reactome_reaction,uniprot&ids='}},
#  'glytoucan': {'label': 'GlyTouCan',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/glytoucan.hbs',
#   'target': True,
#   'examples': ['G00049MO',
#    'G00056MO',
#    'G99053DY',
#    'G01534TU',
#    'G19749DC',
#    'G11647UD',
#    'G17126MK',
#    'G17173XA',
#    'G64904FE',
#    'G58670TY'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,pubchem_compound,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,pubchem_compound,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,ensembl_gene&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,doid,mondo,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot,hgnc,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=glytoucan,uniprot&ids='}},
#  'mondo': {'label': 'Mondo',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/mondo.hbs',
#   'target': True,
#   'examples': ['0010679', '0011925', '0000355', '0009678', '0016830'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,doid,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,mesh&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,uniprot&ids='}},
#  'mesh': {'label': 'MeSH',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/mesh.hbs',
#   'target': True,
#   'examples': ['D013584', 'D018234', 'D018232', 'D002813'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,doid,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,mondo,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,medgen&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,mondo,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=mesh,medgen,ncbigene,uniprot&ids='}},
#  'nando': {'label': 'NANDO',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/nando.hbs',
#   'target': True,
#   'examples': ['2200856', '2200857', '2200860', '2200861', '2200862'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,medgen,mondo,mesh,chembl_compound,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,medgen,mondo,mesh,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,doid,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,medgen,mondo,mesh,chembl_compound,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=nando,mondo,medgen,ncbigene,uniprot&ids='}},
#  'hp': {'label': 'Human Phenotype Ontology',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/hp.hbs',
#   'target': True,
#   'examples': ['0012570', '0012218', '0006779', '0006765'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh,chembl_compound,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,doid,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,hgnc&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,mondo,mesh,chembl_compound,pubchem_compound&ids=',
#    'togovar': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,togovar&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=hp,medgen,ncbigene,uniprot&ids='}},
#  'togovar': {'label': 'TogoVar variant',
#   'template': 'https://raw.githubusercontent.com/togodx/togodx-config-human/develop/templates/togovar.hbs',
#   'target': False,
#   'examples': ['tgv100005930',
#    'tgv100000890',
#    'tgv16331',
#    'tgv10000341',
#    'tgv21330879'],
#   'conversion': {'chebi': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,reactome_reaction,chebi&ids=',
#    'chembl_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,reactome_reaction,chebi,chembl_compound&ids=',
#    'chembl_target': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,chembl_target&ids=',
#    'ensembl_gene': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,ensembl_gene&ids=',
#    'glytoucan': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,glytoucan&ids=',
#    'hgnc': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc&ids=',
#    'hp': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,hp&ids=',
#    'medgen': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen&ids=',
#    'mesh': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,mesh&ids=',
#    'mondo': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,mondo&ids=',
#    'nando': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,mondo,nando&ids=',
#    'ncbigene': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,ncbigene&ids=',
#    'omim_phenotype': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,omim_phenotype&ids=',
#    'orphanet': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,medgen,orphanet&ids=',
#    'pdb': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,pdb&ids=',
#    'pubchem_compound': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot,reactome_reaction,chebi,pubchem_compound&ids=',
#    'uniprot': 'https://api.togoid.dbcls.jp/convert?format=json&route=togovar,hgnc,uniprot&ids='}}}

# %%
# Connecting outer nodes (!= primary dataset, the network hub node)
for index, row in outer_entries.iterrows():
    for target in outer_entries['dest_dataset'].unique():
        # Loop for the datasets other than itself
        if target != row['dest_dataset']:
            time.sleep(1)
            print('from: ' + row['dest_dataset'] + ' to: ' + target)
            
            config_dataset = datasets_dict[row['dest_dataset']]['conversion']
            if not target in config_dataset:
                continue

            togoid_api_route = config_dataset[target]
            api_url = togoid_api_route + row['dest_entry']
            print(api_url)
            
            res_json = urlopen(api_url)
            res = json.loads(res_json.read())

            n_from = row['dest_dataset'] + ':' + row['dest_entry']
            for i in res['results']:
                n_to = target + ':' + i
                print('Edge from:' + n_from + ', to: ' + n_to)
                net.add_node(n_to)
                net.add_edge(n_from, n_to)
# Out:
# from: ensembl_transcript to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene&ids=ENST00000379939
# Edge from:ensembl_transcript:ENST00000379939, to: ncbigene:26960
# from: ensembl_transcript to: uniprot
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,uniprot&ids=ENST00000379939
# Edge from:ensembl_transcript:ENST00000379939, to: uniprot:Q5T321
# from: ensembl_transcript to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene,medgen,mondo&ids=ENST00000379939
# Edge from:ensembl_transcript:ENST00000379939, to: mondo:0030930
# from: ensembl_transcript to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene&ids=ENST00000400445
# Edge from:ensembl_transcript:ENST00000400445, to: ncbigene:26960
# from: ensembl_transcript to: uniprot
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,uniprot&ids=ENST00000400445
# Edge from:ensembl_transcript:ENST00000400445, to: uniprot:Q8NFP9-1
# from: ensembl_transcript to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene,medgen,mondo&ids=ENST00000400445
# Edge from:ensembl_transcript:ENST00000400445, to: mondo:0030930
# from: ensembl_transcript to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene&ids=ENST00000537702
# Edge from:ensembl_transcript:ENST00000537702, to: ncbigene:26960
# from: ensembl_transcript to: uniprot
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,uniprot&ids=ENST00000537702
# Edge from:ensembl_transcript:ENST00000537702, to: uniprot:Q8NFP9-3
# from: ensembl_transcript to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene,medgen,mondo&ids=ENST00000537702
# Edge from:ensembl_transcript:ENST00000537702, to: mondo:0030930
# from: ensembl_transcript to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene&ids=ENST00000629018
# from: ensembl_transcript to: uniprot
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,uniprot&ids=ENST00000629018
# Edge from:ensembl_transcript:ENST00000629018, to: uniprot:A0A0D9SF28
# from: ensembl_transcript to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=ensembl_transcript,ncbigene,medgen,mondo&ids=ENST00000629018
# from: ncbigene to: ensembl_transcript
# from: ncbigene to: uniprot
# https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,uniprot&ids=26960
# Edge from:ncbigene:26960, to: uniprot:Q8NFP9
# Edge from:ncbigene:26960, to: uniprot:Q5T321
# Edge from:ncbigene:26960, to: uniprot:B3KXQ8
# from: ncbigene to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=ncbigene,medgen,mondo&ids=26960
# Edge from:ncbigene:26960, to: mondo:0030930
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A0D9SF28
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A0D9SF28
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KQL6
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KQL6
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KQP5
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KQP5
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KRX1
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KRX1
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KRZ1
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KRZ1
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KS18
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KS18
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KS58
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KS58
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KSX3
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KSX3
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KTV6
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KTV6
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KTY1
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KTY1
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KWL1
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KWL1
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KX92
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KX92
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KXL4
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KXL4
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KXR7
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KXR7
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KXW8
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KXW8
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KXY8
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KXY8
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5KZ13
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5KZ13
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5QJB2
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5QJB2
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5QJQ0
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5QJQ0
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5QKR1
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5QKR1
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=A0A8I5QKR6
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=A0A8I5QKR6
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=Q5T321
# Edge from:uniprot:Q5T321, to: ncbigene:26960
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=Q5T321
# Edge from:uniprot:Q5T321, to: mondo:0030930
# from: uniprot to: ensembl_transcript
# from: uniprot to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene&ids=Q8NFP9
# Edge from:uniprot:Q8NFP9, to: ncbigene:26960
# from: uniprot to: mondo
# https://api.togoid.dbcls.jp/convert?format=json&route=uniprot,ncbigene,medgen,mondo&ids=Q8NFP9
# Edge from:uniprot:Q8NFP9, to: mondo:0030930
# from: mondo to: ensembl_transcript
# from: mondo to: ncbigene
# https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene&ids=0030930
# Edge from:mondo:0030930, to: ncbigene:26960
# from: mondo to: uniprot
# https://api.togoid.dbcls.jp/convert?format=json&route=mondo,medgen,ncbigene,uniprot&ids=0030930
# Edge from:mondo:0030930, to: uniprot:Q8NFP9
# Edge from:mondo:0030930, to: uniprot:Q5T321
# Edge from:mondo:0030930, to: uniprot:B3KXQ8

# %%
net.toggle_physics(True)
net.show('mygraph.html')
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="mygraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
